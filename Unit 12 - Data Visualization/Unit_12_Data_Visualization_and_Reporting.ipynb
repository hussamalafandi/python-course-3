# %% [markdown]
# # Unit 12 – Data Visualization & Reporting
#
# ## 🎯 Learning Objectives
#
# By the end of this unit, you will be able to:
#
# 1. Understand the fundamentals of data visualization and why it matters
# 2. Create various types of plots using **Matplotlib**
# 3. Build beautiful statistical visualizations with **Seaborn**
# 4. Choose the appropriate chart type for different data scenarios
# 5. Tell compelling stories with data through effective visualization
#
# ---
#
# ## 📚 Table of Contents
#
# 1. [Visualization Fundamentals](#1-visualization-fundamentals)
# 2. [Matplotlib Basics](#2-matplotlib-basics)
# 3. [Seaborn Overview](#3-seaborn-overview)
# 4. [Choosing the Right Chart](#4-choosing-the-right-chart)
# 5. [Storytelling with Data](#5-storytelling-with-data)
# 6. [Practice Projects](#6-practice-projects)

# %% [markdown]
# ---
#
# # 1. Visualization Fundamentals
#
# ## Why Data Visualization Matters
#
# Data visualization is the graphical representation of information and data. It transforms raw numbers into visual stories that our brains can process much faster than tables of numbers.
#
# ### The Power of Visualization
#
# **Consider this:** The human brain processes visual information **60,000 times faster** than text. A well-designed chart can communicate insights in seconds that might take minutes to explain with words.
#
# ### Key Principles of Effective Visualization
#
# | Principle | Description | Example |
# |-----------|-------------|----------|
# | **Clarity** | The message should be immediately clear | Avoid 3D effects that distort perception |
# | **Accuracy** | Data should be represented truthfully | Start y-axis at 0 for bar charts |
# | **Efficiency** | Maximize data-ink ratio | Remove unnecessary gridlines and decorations |
# | **Aesthetics** | Visual appeal increases engagement | Use consistent color palettes |
#
# ### The Grammar of Graphics
#
# Every visualization consists of these components:
#
# - **Data**: The information you want to visualize
# - **Aesthetics**: How data maps to visual properties (position, color, size)
# - **Geometries**: The visual elements (points, lines, bars)
# - **Scales**: How data values translate to visual values
# - **Labels & Annotations**: Context and explanation

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# IMPORTING LIBRARIES - The Foundation of Data Visualization
# ═══════════════════════════════════════════════════════════════════════════════

# To install these libraries (run once if not installed):
# !pip install matplotlib seaborn pandas numpy

# ─────────────────────────────────────────────────────────────────────────────
# IMPORT STATEMENTS EXPLAINED:
# ─────────────────────────────────────────────────────────────────────────────

# matplotlib.pyplot: The main plotting module
# - 'as plt' creates a shorter alias so we can write plt.plot() instead of matplotlib.pyplot.plot()
import matplotlib.pyplot as plt

# seaborn: A statistical visualization library built on matplotlib
# - Makes beautiful plots with less code
# - 'as sns' is the conventional alias (named after Samuel Norman Seaborn)
import seaborn as sns

# pandas: Data manipulation library
# - Used for handling DataFrames (spreadsheet-like data structures)
# - 'as pd' is the standard convention
import pandas as pd

# numpy: Numerical computing library
# - Provides arrays and mathematical functions
# - 'as np' is the standard convention
import numpy as np

# ─────────────────────────────────────────────────────────────────────────────
# SETTING UP THE VISUAL STYLE:
# ─────────────────────────────────────────────────────────────────────────────

# plt.style.use() - Sets the overall visual style for ALL plots
# 'seaborn-v0_8-whitegrid' gives us:
#   - Clean white background
#   - Light gray grid lines
#   - Professional look
# Other options: 'ggplot', 'dark_background', 'bmh', 'fivethirtyeight'
plt.style.use('seaborn-v0_8-whitegrid')

# sns.set_palette() - Sets the default color scheme for seaborn plots
# "husl" is a colorful, evenly-spaced color palette
# Other options: "deep", "muted", "bright", "pastel", "dark", "colorblind"
sns.set_palette("husl")

# ─────────────────────────────────────────────────────────────────────────────
# RANDOM SEED FOR REPRODUCIBILITY:
# ─────────────────────────────────────────────────────────────────────────────

# np.random.seed(42) ensures that random numbers are the same every time
# This is crucial for tutorials so everyone gets identical results
# The number 42 is arbitrary (a reference to "Hitchhiker's Guide to the Galaxy")
np.random.seed(42)

# ─────────────────────────────────────────────────────────────────────────────
# VERIFICATION:
# ─────────────────────────────────────────────────────────────────────────────

print("✅ Libraries imported successfully!")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")

# %% [markdown]
# ### 🏭 Real-World Example: Why Visualization Beats Tables
#
# Let's demonstrate with **Anscombe's Quartet** - four datasets that have nearly identical statistical properties but look completely different when visualized.
#
# #### What We'll Learn:
# - Loading built-in datasets with Seaborn
# - Using `groupby()` and `agg()` for statistical summaries
# - Why numbers alone can be deceiving

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# ANSCOMBE'S QUARTET - Why Visualization is Essential
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# LOADING A BUILT-IN DATASET:
# ─────────────────────────────────────────────────────────────────────────────

# sns.load_dataset('name') loads a famous dataset that comes with Seaborn
# Available datasets: 'tips', 'iris', 'titanic', 'penguins', 'flights', etc.
# This returns a pandas DataFrame - a table-like data structure
anscombe = sns.load_dataset('anscombe')

# Let's look at the structure of our data
print("📋 Dataset Structure:")
print(f"   Shape: {anscombe.shape} (rows, columns)")
print(f"   Columns: {list(anscombe.columns)}")
print("\n📊 First few rows:")
print(anscombe.head(10))

# ─────────────────────────────────────────────────────────────────────────────
# CALCULATING GROUPED STATISTICS:
# ─────────────────────────────────────────────────────────────────────────────

# groupby('column') - Groups data by unique values in a column
# .agg({}) - Applies aggregation functions to specified columns
# 
# The syntax for agg():
#   {'column_name': ['function1', 'function2']}
# 
# Common aggregation functions:
#   'mean' - average value
#   'std'  - standard deviation (spread of data)
#   'min', 'max' - minimum and maximum
#   'count' - number of values
#   'sum'  - total sum

stats = anscombe.groupby('dataset').agg({
    'x': ['mean', 'std'],   # Calculate mean and std for x column
    'y': ['mean', 'std']    # Calculate mean and std for y column
}).round(2)  # .round(2) rounds all numbers to 2 decimal places

print("\n" + "="*60)
print("📊 Statistics look almost identical for all 4 datasets:")
print("="*60)
print(stats)
print("\n🤔 But are they really the same? Let's visualize...")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CREATING A MULTI-PANEL VISUALIZATION
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# plt.subplots() - The Foundation of Complex Visualizations
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: fig, axes = plt.subplots(nrows, ncols, figsize=(width, height))
#
# Parameters:
#   nrows, ncols: Number of rows and columns in the grid
#   figsize: Tuple of (width, height) in inches
#
# Returns:
#   fig: The entire figure (canvas)
#   axes: Array of individual plot areas (subplots)
#
# Here we create a 2x2 grid of plots:

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# ─────────────────────────────────────────────────────────────────────────────
# fig.suptitle() - Add a Title to the ENTIRE Figure
# ─────────────────────────────────────────────────────────────────────────────
# 
# Parameters:
#   text: The title string
#   fontsize: Size of the font (default is usually 12)
#   fontweight: 'normal', 'bold', 'light', 'heavy'

fig.suptitle("Anscombe's Quartet: Same Statistics, Different Stories!", 
             fontsize=14, fontweight='bold')

# ─────────────────────────────────────────────────────────────────────────────
# PREPARING DATA FOR PLOTTING:
# ─────────────────────────────────────────────────────────────────────────────

# Lists to iterate through
datasets = ['I', 'II', 'III', 'IV']  # Names of the four datasets
colors = ['#e74c3c', '#3498db', '#2ecc71', '#9b59b6']  # Hex color codes

# ─────────────────────────────────────────────────────────────────────────────
# LOOPING THROUGH SUBPLOTS:
# ─────────────────────────────────────────────────────────────────────────────
# 
# axes.flat - Flattens the 2D array of axes into a 1D iterator
# zip() - Combines multiple iterables together
#
# Example: zip([1,2], ['a','b']) → [(1,'a'), (2,'b')]

for ax, dataset, color in zip(axes.flat, datasets, colors):
    # ─────────────────────────────────────────────────────────────────────────
    # FILTERING DATA:
    # ─────────────────────────────────────────────────────────────────────────
    # Boolean indexing: df[df['column'] == value] filters rows
    data = anscombe[anscombe['dataset'] == dataset]
    
    # ─────────────────────────────────────────────────────────────────────────
    # ax.scatter() - Create a Scatter Plot
    # ─────────────────────────────────────────────────────────────────────────
    # 
    # Essential Parameters:
    #   x, y: Data for horizontal and vertical positions
    #   s: Size of markers (in points squared, default=20)
    #   color: Color of markers (name, hex code, or RGB tuple)
    #   alpha: Transparency (0=invisible, 1=opaque)
    #   edgecolors: Color of marker borders
    #   linewidth: Width of marker borders
    
    ax.scatter(data['x'], data['y'], 
               s=80,              # Size of points
               color=color,       # Fill color
               alpha=0.7,         # 70% opaque
               edgecolors='white', # White border
               linewidth=2)       # Border width
    
    # ─────────────────────────────────────────────────────────────────────────
    # CUSTOMIZING INDIVIDUAL SUBPLOTS:
    # ─────────────────────────────────────────────────────────────────────────
    
    ax.set_title(f'Dataset {dataset}', fontsize=12, fontweight='bold')  # Subplot title
    ax.set_xlabel('X')  # X-axis label
    ax.set_ylabel('Y')  # Y-axis label
    ax.set_xlim(3, 20)  # X-axis range: from 3 to 20
    ax.set_ylim(3, 14)  # Y-axis range: from 3 to 14
    
    # ─────────────────────────────────────────────────────────────────────────
    # ADDING A REGRESSION (TREND) LINE:
    # ─────────────────────────────────────────────────────────────────────────
    # 
    # np.polyfit(x, y, degree) - Fits a polynomial of given degree
    #   degree=1 means a straight line (y = mx + b)
    #   Returns coefficients [m, b]
    #
    # np.poly1d(coefficients) - Creates a polynomial function
    #   Can then be called like: p(x_values) to get y_values
    
    z = np.polyfit(data['x'], data['y'], 1)  # Fit a line
    p = np.poly1d(z)                          # Create the line function
    
    # ─────────────────────────────────────────────────────────────────────────
    # ax.plot() - Draw Lines
    # ─────────────────────────────────────────────────────────────────────────
    # 
    # Parameters:
    #   x, y: Data points
    #   color: Line color
    #   linestyle: '-' solid, '--' dashed, '-.' dash-dot, ':' dotted
    #   alpha: Transparency
    #   linewidth: Thickness of the line
    
    ax.plot(data['x'].sort_values(),           # X values (sorted)
            p(data['x'].sort_values()),         # Y values from our line function
            color=color, 
            linestyle='--',                     # Dashed line
            alpha=0.5,                          # Semi-transparent
            linewidth=2)

# ─────────────────────────────────────────────────────────────────────────────
# FINAL LAYOUT ADJUSTMENTS:
# ─────────────────────────────────────────────────────────────────────────────

# plt.tight_layout() - Automatically adjusts spacing to prevent overlapping
# This is ESSENTIAL for multi-panel figures!
plt.tight_layout()

# plt.show() - Display the figure
# In Jupyter, this renders the plot below the cell
plt.show()

print("\n💡 KEY INSIGHT: Always visualize your data!")
print("   These four datasets have IDENTICAL means, variances, and correlations,")
print("   but they tell completely different stories when visualized!")

# %% [markdown]
# ---
#
# # 2. Matplotlib Basics
#
# **Matplotlib** is the foundational plotting library in Python. It provides complete control over every aspect of your visualizations.
#
# ## Understanding the Matplotlib Architecture
#
# ```
# Figure (the entire window/page)
# │
# ├── Axes (individual plot area)
# │   ├── Title
# │   ├── X-axis (with label, ticks)
# │   ├── Y-axis (with label, ticks)
# │   ├── Plot elements (lines, bars, scatter)
# │   └── Legend
# │
# └── Additional Axes (for subplots)
# ```
#
# ## Two Approaches to Matplotlib
#
# 1. **Pyplot Interface** (Quick and simple): `plt.plot()`
# 2. **Object-Oriented Interface** (More control): `fig, ax = plt.subplots()`

# %% [markdown]
# ## 2.1 Line Plots
#
# **Best for:** Time series data, trends over continuous intervals, showing change
#
# ### 🏢 Real-World Use Case: Company Revenue Over Time
#
# ---
#
# ### Key Commands We'll Learn:
#
# | Command | Purpose |
# |---------|---------|
# | `plt.subplots()` | Create figure and axes |
# | `ax.plot()` | Draw lines connecting points |
# | `ax.fill_between()` | Shade area between two lines |
# | `ax.annotate()` | Add text with arrows |
# | `ax.set_xlabel/ylabel()` | Label axes |
# | `ax.legend()` | Add legend |
# | `plt.FuncFormatter()` | Custom axis formatting |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# LINE PLOT TUTORIAL - Company Financial Performance
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# STEP 1: PREPARE THE DATA
# ─────────────────────────────────────────────────────────────────────────────

# pd.date_range() - Creates a sequence of dates
# Parameters:
#   start: Starting date (string like '2024-01' or datetime object)
#   periods: Number of dates to generate
#   freq: Frequency - 'M' (month end), 'D' (daily), 'W' (weekly), 'Y' (yearly)

months = pd.date_range('2024-01', periods=24, freq='M')
print(f"Generated {len(months)} monthly dates from {months[0].strftime('%B %Y')} to {months[-1].strftime('%B %Y')}")

# Our financial data (in dollars)
revenue = [45000, 52000, 48000, 61000, 67000, 72000, 78000, 85000, 91000, 98000, 105000, 125000,
           132000, 145000, 158000, 172000, 185000, 195000, 210000, 225000, 242000, 265000, 285000, 310000]
expenses = [40000, 45000, 43000, 50000, 55000, 58000, 62000, 68000, 72000, 78000, 82000, 95000,
            100000, 108000, 115000, 125000, 132000, 140000, 150000, 160000, 172000, 185000, 195000, 210000]

# ─────────────────────────────────────────────────────────────────────────────
# STEP 2: CREATE THE FIGURE AND AXES
# ─────────────────────────────────────────────────────────────────────────────

# plt.subplots() returns two objects:
#   fig: The entire figure (like the canvas)
#   ax: The axes (where we draw our plot)
# 
# figsize=(width, height) in inches - affects export resolution too!

fig, ax = plt.subplots(figsize=(14, 6))

# ─────────────────────────────────────────────────────────────────────────────
# STEP 3: PLOT THE DATA WITH ax.plot()
# ─────────────────────────────────────────────────────────────────────────────

# ax.plot() - The fundamental line plotting command
#
# COMPLETE PARAMETER REFERENCE:
# ───────────────────────────────────────────────────────────────────────────
# x, y            : Data to plot (arrays, lists, or Series)
# color           : Line color - name ('red'), hex ('#27ae60'), RGB tuple
# linewidth (lw)  : Thickness of line in points
# linestyle (ls)  : '-' solid, '--' dashed, '-.' dash-dot, ':' dotted
# marker          : Shape at data points: 'o' circle, 's' square, '^' triangle
#                   'd' diamond, 'x' X, '+' plus, '*' star
# markersize (ms) : Size of markers in points
# markevery       : Show marker every N points (int) or at specific indices (list)
# label           : Text for legend
# alpha           : Transparency (0 to 1)

# Plot Revenue line (green, solid, circle markers)
ax.plot(months, revenue, 
        marker='o',           # Circle markers at each data point
        linewidth=2.5,        # Thick line for visibility
        markersize=6,         # Size of the circles
        color='#27ae60',      # Green (hex color code)
        label='Revenue',      # Label for legend
        linestyle='-')        # Solid line

# Plot Expenses line (red, dashed, square markers)
ax.plot(months, expenses, 
        marker='s',           # Square markers
        linewidth=2.5,        
        markersize=6,         
        color='#e74c3c',      # Red
        label='Expenses',     
        linestyle='--')       # Dashed line

# ─────────────────────────────────────────────────────────────────────────────
# STEP 4: ADD FILLED AREA WITH ax.fill_between()
# ─────────────────────────────────────────────────────────────────────────────

# ax.fill_between() - Fills the area between two horizontal lines
#
# Parameters:
#   x:     The x-coordinates (shared by both lines)
#   y1:    The first line (bottom boundary)
#   y2:    The second line (top boundary) - if omitted, fills to 0
#   alpha: Transparency of the fill
#   color: Fill color
#   label: Label for legend

ax.fill_between(months, expenses, revenue,  # Fill between expenses and revenue
                alpha=0.3,                  # 30% opacity (subtle)
                color='#27ae60',            # Green fill
                label='Profit')

# ─────────────────────────────────────────────────────────────────────────────
# STEP 5: CUSTOMIZE THE PLOT
# ─────────────────────────────────────────────────────────────────────────────

# ax.set_title() - Add title to the axes
# Parameters:
#   label: Title text
#   fontsize: Font size in points
#   fontweight: 'normal', 'bold', 'light', etc.
#   pad: Space between title and plot (in points)

ax.set_title('🚀 TechStartup Inc. - Financial Performance (2024-2025)', 
             fontsize=14, fontweight='bold', pad=15)

# ax.set_xlabel() and ax.set_ylabel() - Label the axes
ax.set_xlabel('Month', fontsize=11)
ax.set_ylabel('Amount ($)', fontsize=11)

# ax.legend() - Add legend showing what each line represents
# Parameters:
#   loc: Position - 'upper left', 'upper right', 'lower left', 'lower right',
#        'center', 'best' (automatic), or coordinates (x, y)
#   frameon: Show border around legend
#   fancybox: Rounded corners
#   shadow: Add shadow effect

ax.legend(loc='upper left', frameon=True, fancybox=True, shadow=True)

# ax.grid() - Add gridlines
# Parameters:
#   visible: True/False
#   alpha: Transparency of gridlines

ax.grid(True, alpha=0.3)

# ─────────────────────────────────────────────────────────────────────────────
# STEP 6: CUSTOM AXIS FORMATTING
# ─────────────────────────────────────────────────────────────────────────────

# plt.FuncFormatter() - Custom formatting for axis tick labels
# Takes a function that receives (value, position) and returns a string
#
# Here we format numbers as currency: 50000 → "$50K"
# Lambda function: lambda x, p: f'${x/1000:.0f}K'
#   x: the tick value
#   p: the tick position (unused here)
#   f'${x/1000:.0f}K': Format string
#       x/1000: Divide by 1000
#       :.0f: Format as float with 0 decimal places
#       $...K: Add dollar sign and K suffix

ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# ─────────────────────────────────────────────────────────────────────────────
# STEP 7: ADD ANNOTATIONS
# ─────────────────────────────────────────────────────────────────────────────

# ax.annotate() - Add text with optional arrow pointing to data
#
# Parameters:
#   text: The annotation text
#   xy: Point to annotate (x, y) - where the arrow points TO
#   xytext: Position of text (x, y) - where the text sits
#   fontsize: Size of annotation text
#   ha: Horizontal alignment ('left', 'center', 'right')
#   va: Vertical alignment ('top', 'center', 'bottom')
#   arrowprops: Dictionary controlling the arrow appearance
#       arrowstyle: '->', '-', 'fancy', 'simple', 'wedge'
#       color: Arrow color
#       lw: Line width
#   bbox: Dictionary for text box background
#       boxstyle: 'round', 'square', 'circle', etc.
#       facecolor: Background color
#       alpha: Transparency

ax.annotate('Break-even\nAchieved! 🎉',           # The text (\\n for newline)
            xy=(months[5], revenue[5]),           # Point to annotate (June revenue)
            xytext=(months[3], 85000),            # Where to place the text
            fontsize=10, 
            ha='center',                          # Center the text horizontally
            arrowprops=dict(arrowstyle='->',      # Arrow style
                           color='gray', 
                           lw=1.5),               # Arrow line width
            bbox=dict(boxstyle='round,pad=0.3',   # Rounded box with padding
                     facecolor='yellow', 
                     alpha=0.7))

# ─────────────────────────────────────────────────────────────────────────────
# STEP 8: FINAL ADJUSTMENTS
# ─────────────────────────────────────────────────────────────────────────────

# plt.xticks(rotation=...) - Rotate x-axis tick labels
# Useful when labels are long or overlap
plt.xticks(rotation=45)

# plt.tight_layout() - Automatically adjust spacing
# Prevents labels from being cut off
plt.tight_layout()

# plt.show() - Display the plot
plt.show()

# ─────────────────────────────────────────────────────────────────────────────
# SUMMARY OF KEY COMMANDS:
# ─────────────────────────────────────────────────────────────────────────────
print("\n📚 LINE PLOT COMMANDS SUMMARY:")
print("   • ax.plot(x, y, ...)        → Draw lines/markers")
print("   • ax.fill_between(...)      → Shade areas")
print("   • ax.set_title/xlabel/ylabel → Add labels")
print("   • ax.legend()               → Add legend")
print("   • ax.annotate()             → Add annotations with arrows")
print("   • ax.yaxis.set_major_formatter() → Custom tick formatting")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# LINE STYLES AND MARKERS REFERENCE GUIDE
# ═══════════════════════════════════════════════════════════════════════════════

# This cell demonstrates ALL the different line styles and markers available

fig, ax = plt.subplots(figsize=(12, 5))

# ─────────────────────────────────────────────────────────────────────────────
# np.linspace() - Create Evenly Spaced Numbers
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: np.linspace(start, stop, num)
# 
# Parameters:
#   start: Starting value
#   stop: Ending value (included)
#   num: Number of points to generate
#
# Returns an array of evenly spaced values
# Example: np.linspace(0, 10, 5) → [0.0, 2.5, 5.0, 7.5, 10.0]

x = np.linspace(0, 10, 50)  # 50 points from 0 to 10
print(f"Created {len(x)} x-values from {x[0]} to {x[-1]}")

# ─────────────────────────────────────────────────────────────────────────────
# LINE STYLES AND MARKERS REFERENCE:
# ─────────────────────────────────────────────────────────────────────────────
#
# LINE STYLES:
#   '-'   : Solid line
#   '--'  : Dashed line
#   '-.'  : Dash-dot line
#   ':'   : Dotted line
#
# COMMON MARKERS:
#   'o'   : Circle
#   's'   : Square
#   '^'   : Triangle up
#   'v'   : Triangle down
#   'd'   : Diamond (thin)
#   'D'   : Diamond (thick)
#   '+'   : Plus
#   'x'   : X
#   '*'   : Star
#   'p'   : Pentagon
#   'h'   : Hexagon

styles = [
    ('-', 'o', 'Solid + Circle'),
    ('--', 's', 'Dashed + Square'),
    ('-.', '^', 'Dash-dot + Triangle'),
    (':', 'D', 'Dotted + Diamond')
]

# Loop through each style combination
for i, (linestyle, marker, label) in enumerate(styles):
    # np.sin() - Calculate sine of each value
    # Adding i*0.5 shifts the wave to avoid overlap
    y = np.sin(x + i*0.5)
    
    ax.plot(x, y, 
            linestyle=linestyle,  # Line style from our list
            marker=marker,        # Marker type from our list
            markevery=5,          # Only show marker every 5th point (reduces clutter)
            label=label,          # Label for legend
            linewidth=2,          # Line thickness
            markersize=8)         # Marker size

ax.set_title('📖 Matplotlib Line Styles & Markers Reference', fontsize=12, fontweight='bold')
ax.legend(loc='upper right')
ax.set_xlabel('X values')
ax.set_ylabel('Y values')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# ─────────────────────────────────────────────────────────────────────────────
# COMPLETE MARKER REFERENCE (for your reference):
# ─────────────────────────────────────────────────────────────────────────────
print("\n📌 COMPLETE MARKER REFERENCE:")
print("   'o' → Circle        's' → Square       '^' → Triangle Up")
print("   'v' → Triangle Down '<' → Triangle Left '>' → Triangle Right")
print("   'd' → Thin Diamond  'D' → Thick Diamond 'p' → Pentagon")
print("   'h' → Hexagon       '*' → Star         '+' → Plus")
print("   'x' → X             '.' → Point        ',' → Pixel")

# %% [markdown]
# ## 2.2 Bar Charts
#
# **Best for:** Comparing discrete categories, showing rankings, part-to-whole relationships
#
# ### 🛒 Real-World Use Case: E-commerce Sales by Product Category
#
# ---
#
# ### Key Commands We'll Learn:
#
# | Command | Purpose |
# |---------|---------|
# | `ax.bar()` | Create vertical bar chart |
# | `ax.barh()` | Create horizontal bar chart |
# | `np.arange()` | Generate array of numbers |
# | `ax.set_xticks()` | Set tick positions |
# | `ax.set_xticklabels()` | Set tick labels |
# | `ax.text()` | Add text anywhere on plot |
#
# ### When to Use Bar Charts:
# - **Vertical bars**: Comparing categories (time on x-axis)
# - **Horizontal bars**: Rankings or long category names
# - **Grouped bars**: Comparing multiple series
# - **Stacked bars**: Part-to-whole relationships

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BAR CHART TUTORIAL - E-commerce Sales Analysis
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# STEP 1: PREPARE THE DATA
# ─────────────────────────────────────────────────────────────────────────────

# Category names (for x-axis labels)
categories = ['Electronics', 'Clothing', 'Home & Garden', 'Books', 'Sports', 'Toys', 'Beauty']

# Sales data for two quarters
sales_q1 = [125000, 98000, 76000, 45000, 67000, 52000, 89000]  # Q1 sales
sales_q2 = [142000, 105000, 82000, 48000, 78000, 61000, 95000]  # Q2 sales

# ─────────────────────────────────────────────────────────────────────────────
# np.arange() - Create Array of Sequential Numbers
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: np.arange(stop) or np.arange(start, stop, step)
# 
# Examples:
#   np.arange(5)      → [0, 1, 2, 3, 4]
#   np.arange(2, 8)   → [2, 3, 4, 5, 6, 7]
#   np.arange(0, 10, 2) → [0, 2, 4, 6, 8]
#
# We use this to create x-positions for our bars

x = np.arange(len(categories))  # [0, 1, 2, 3, 4, 5, 6] - one position per category
width = 0.35  # Width of each bar (as fraction of distance between positions)

print(f"X positions for bars: {x}")
print(f"Bar width: {width}")

# ─────────────────────────────────────────────────────────────────────────────
# STEP 2: CREATE FIGURE WITH TWO SUBPLOTS SIDE BY SIDE
# ─────────────────────────────────────────────────────────────────────────────

# When you specify (1, 2), you get 1 row and 2 columns
# axes will be a 1D array: [axes[0], axes[1]]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 1: GROUPED BAR CHART
# ═══════════════════════════════════════════════════════════════════════════════

ax1 = axes[0]

# ─────────────────────────────────────────────────────────────────────────────
# ax.bar() - Create Vertical Bar Chart
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: ax.bar(x, height, width, **kwargs)
#
# ESSENTIAL PARAMETERS:
#   x:         Position of bars on x-axis
#   height:    Height of each bar (your data values)
#   width:     Width of bars (0.0 to 1.0, default=0.8)
#   
# STYLING PARAMETERS:
#   color:     Fill color
#   edgecolor: Border color
#   linewidth: Border thickness
#   alpha:     Transparency
#   label:     Legend text
#   bottom:    Where bar starts (for stacked bars)

# For grouped bars, we offset each group by half the width
# First group: x - width/2 (shifted left)
# Second group: x + width/2 (shifted right)

bars1 = ax1.bar(x - width/2,        # Positions (shifted left)
                sales_q1,            # Heights (the data)
                width,               # Width of bars
                label='Q1 2025',     # Legend label
                color='#3498db',     # Blue
                edgecolor='white')   # White border

bars2 = ax1.bar(x + width/2,        # Positions (shifted right)
                sales_q2,            # Heights
                width,               
                label='Q2 2025',     
                color='#e74c3c',     # Red
                edgecolor='white')

# ─────────────────────────────────────────────────────────────────────────────
# CUSTOMIZING X-AXIS TICKS AND LABELS:
# ─────────────────────────────────────────────────────────────────────────────
# 
# ax.set_xticks(positions) - Where to place ticks
# ax.set_xticklabels(labels, rotation=..., ha=...) - What text to show
#   rotation: Angle of labels in degrees
#   ha: Horizontal alignment ('left', 'center', 'right')

ax1.set_xticks(x)                    # Ticks at positions 0, 1, 2, 3, 4, 5, 6
ax1.set_xticklabels(categories,      # Use category names as labels
                    rotation=45,      # Rotate 45 degrees
                    ha='right')       # Align right (looks better when rotated)

ax1.set_title('📊 Quarterly Sales Comparison by Category', fontsize=12, fontweight='bold')
ax1.set_xlabel('Product Category')
ax1.set_ylabel('Sales ($)')
ax1.legend()

# Format y-axis as currency
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# ─────────────────────────────────────────────────────────────────────────────
# ADDING VALUE LABELS ON TOP OF BARS:
# ─────────────────────────────────────────────────────────────────────────────
# 
# ax.annotate() places text at a specific point
# We loop through each bar and add its value above it

for bar in bars1:
    height = bar.get_height()  # Get the height of this bar
    ax1.annotate(f'${height/1000:.0f}K',                    # Text to display
                 xy=(bar.get_x() + bar.get_width() / 2,     # X position (center of bar)
                     height),                                # Y position (top of bar)
                 xytext=(0, 3),                             # Offset: 0 horizontal, 3 points up
                 textcoords="offset points",                 # Interpret xytext as offset
                 ha='center',                                # Center horizontally
                 va='bottom',                                # Align to bottom of text
                 fontsize=8)

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 2: HORIZONTAL BAR CHART (for rankings)
# ═══════════════════════════════════════════════════════════════════════════════

ax2 = axes[1]

# Calculate total sales and sort for ranking
total_sales = [q1 + q2 for q1, q2 in zip(sales_q1, sales_q2)]

# zip() and sorted() to sort both lists together
# sorted(..., key=lambda x: x[1]) sorts by the second element (sales)
sorted_data = sorted(zip(categories, total_sales), key=lambda x: x[1])
cats_sorted, sales_sorted = zip(*sorted_data)  # Unpack into two tuples

print(f"\nSorted categories by total sales: {cats_sorted}")

# ─────────────────────────────────────────────────────────────────────────────
# ax.barh() - Create Horizontal Bar Chart
# ─────────────────────────────────────────────────────────────────────────────
# 
# Same as bar() but swaps x and y
# Syntax: ax.barh(y, width, **kwargs)
#
# When to use horizontal bars:
#   - Long category names
#   - Rankings (best at top or bottom)
#   - Many categories

# Create a color gradient using a colormap
# plt.cm.RdYlGn is Red-Yellow-Green colormap
# np.linspace(0.2, 0.8, n) creates n values from 0.2 to 0.8
colors = plt.cm.RdYlGn(np.linspace(0.2, 0.8, len(cats_sorted)))

bars = ax2.barh(cats_sorted,    # Categories (y-axis)
                sales_sorted,    # Values (x-axis = bar length)
                color=colors,    # Gradient colors
                edgecolor='white')

ax2.set_title('🏆 Total Sales Ranking (Q1 + Q2)', fontsize=12, fontweight='bold')
ax2.set_xlabel('Total Sales ($)')
ax2.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# ─────────────────────────────────────────────────────────────────────────────
# ax.text() - Add Text at Any Position
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: ax.text(x, y, text, **kwargs)
# 
# Parameters:
#   x, y: Position in data coordinates
#   text: The string to display
#   va: Vertical alignment ('top', 'center', 'bottom')
#   ha: Horizontal alignment ('left', 'center', 'right')
#   fontsize, fontweight, color, etc.

# Add value labels at the end of each bar
for bar, val in zip(bars, sales_sorted):
    ax2.text(val + 5000,                           # X position (just after bar end)
             bar.get_y() + bar.get_height()/2,     # Y position (center of bar)
             f'${val/1000:.0f}K',                  # The text
             va='center',                           # Vertically centered
             fontsize=9)

plt.tight_layout()
plt.show()

# ─────────────────────────────────────────────────────────────────────────────
# SUMMARY:
# ─────────────────────────────────────────────────────────────────────────────
print("\n📚 BAR CHART COMMANDS SUMMARY:")
print("   • ax.bar(x, height, width)  → Vertical bars")
print("   • ax.barh(y, width)         → Horizontal bars")
print("   • ax.set_xticks(positions)  → Set tick locations")
print("   • ax.set_xticklabels(labels) → Set tick text")
print("   • ax.text(x, y, text)       → Add text anywhere")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# STACKED BAR CHART - Market Share Analysis
# ═══════════════════════════════════════════════════════════════════════════════

# Stacked bar charts show how a whole is divided into parts
# Perfect for market share, survey responses, time allocation, etc.

# ─────────────────────────────────────────────────────────────────────────────
# PREPARE THE DATA:
# ─────────────────────────────────────────────────────────────────────────────

companies = ['Apple', 'Samsung', 'Xiaomi', 'Oppo', 'Others']
years = ['2021', '2022', '2023', '2024', '2025']

# Market share data (percentage) - each column sums to 100%
market_data = {
    'Apple':   [23, 24, 26, 27, 28],
    'Samsung': [21, 22, 21, 20, 19],
    'Xiaomi':  [14, 15, 14, 15, 16],
    'Oppo':    [10, 11, 12, 12, 13],
    'Others':  [32, 28, 27, 26, 24]
}

fig, ax = plt.subplots(figsize=(12, 7))

# Colors for each company
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

# ─────────────────────────────────────────────────────────────────────────────
# THE STACKING TECHNIQUE:
# ─────────────────────────────────────────────────────────────────────────────
# 
# For stacked bars, each bar needs to know where to START (bottom parameter)
# First bar: bottom = 0
# Second bar: bottom = height of first bar
# Third bar: bottom = height of first + second bar
# etc.
#
# We track this with a "bottom" array that accumulates heights

bottom = np.zeros(len(years))  # Start with zeros: [0, 0, 0, 0, 0]

# Loop through each company and stack their bars
for company, color in zip(companies, colors):
    values = market_data[company]
    
    # ─────────────────────────────────────────────────────────────────────────
    # ax.bar() with bottom parameter for stacking
    # ─────────────────────────────────────────────────────────────────────────
    # 
    # The 'bottom' parameter specifies where each bar starts
    # This creates the stacking effect
    
    ax.bar(years,           # X positions
           values,          # Heights of this segment
           bottom=bottom,   # Where this segment starts (on top of previous)
           label=company,   # Legend label
           color=color,     # Fill color
           edgecolor='white',  # White borders between segments
           width=0.6)       # Bar width
    
    # Add percentage labels in the middle of each segment
    for i, (y, v) in enumerate(zip(years, values)):
        if v > 5:  # Only show label if segment is large enough to fit text
            ax.text(i,                              # X position (bar index)
                    bottom[i] + v/2,                # Y position (middle of segment)
                    f'{v}%',                        # The percentage
                    ha='center', va='center',       # Center the text
                    fontsize=9, color='white', fontweight='bold')
    
    # Update bottom for next company (accumulate heights)
    bottom += values  # Now bottom = [23, 24, 26, 27, 28] after Apple
                      #         then [44, 46, 47, 47, 47] after Samsung, etc.

# ─────────────────────────────────────────────────────────────────────────────
# CUSTOMIZATION:
# ─────────────────────────────────────────────────────────────────────────────

ax.set_title('📱 Global Smartphone Market Share (2021-2025)', fontsize=14, fontweight='bold')
ax.set_xlabel('Year', fontsize=11)
ax.set_ylabel('Market Share (%)', fontsize=11)

# ax.legend() with bbox_to_anchor to place legend outside the plot
# bbox_to_anchor=(x, y) uses axes coordinates (0,0 = bottom-left, 1,1 = top-right)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

ax.set_ylim(0, 105)  # Extend slightly beyond 100% for labels

plt.tight_layout()
plt.show()

print("\n💡 STACKED BAR INSIGHT:")
print("   The 'bottom' parameter is the key to stacking!")
print("   Each segment starts where the previous one ended.")

# %% [markdown]
# ## 2.3 Scatter Plots
#
# **Best for:** Showing relationships between two variables, identifying correlations, outlier detection
#
# ### 🏠 Real-World Use Case: Real Estate Price Analysis
#
# ---
#
# ### Key Commands We'll Learn:
#
# | Command | Purpose |
# |---------|---------|
# | `ax.scatter()` | Create scatter plot |
# | `c` parameter | Color points by a third variable |
# | `s` parameter | Size points by a variable |
# | `cmap` | Apply color maps |
# | `plt.colorbar()` | Add color legend |
# | Correlation analysis | Understanding relationships |
#
# ### Types of Scatter Plots:
# 1. **Basic scatter**: Two variables (x, y)
# 2. **Colored scatter**: Three variables (x, y, color)
# 3. **Bubble chart**: Four variables (x, y, color, size)

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# SCATTER PLOT TUTORIAL - Real Estate Price Analysis
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# STEP 1: GENERATE REALISTIC REAL ESTATE DATA
# ─────────────────────────────────────────────────────────────────────────────

np.random.seed(42)  # For reproducibility
n_houses = 150      # Number of houses in our dataset

# ─────────────────────────────────────────────────────────────────────────────
# np.random.normal() - Generate Random Numbers from Normal Distribution
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: np.random.normal(mean, std_dev, size)
# 
# Parameters:
#   mean: Center of the distribution
#   std_dev: Spread (standard deviation) - 68% of values within ±1 std
#   size: Number of values to generate
#
# .clip(min, max) - Limit values to a range (removes outliers)

# Square footage: Average 2000, spread of 500, min 800, max 4000
sqft = np.random.normal(2000, 500, n_houses).clip(800, 4000)

# ─────────────────────────────────────────────────────────────────────────────
# np.random.choice() - Random Selection from Options
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: np.random.choice(options, size, p=probabilities)
# 
# Parameters:
#   options: List of values to choose from
#   size: Number of selections
#   p: Probability of each option (must sum to 1.0)

# Bedrooms: 2, 3, 4, or 5 with specified probabilities
bedrooms = np.random.choice([2, 3, 4, 5], n_houses, p=[0.15, 0.40, 0.35, 0.10])

# ─────────────────────────────────────────────────────────────────────────────
# np.random.exponential() - Generate Right-Skewed Distribution
# ─────────────────────────────────────────────────────────────────────────────
# 
# Good for: Time-to-event, ages, waiting times
# Most values are small, few are large

# House age: Most are newer, few are old (0-50 years)
age = np.random.exponential(15, n_houses).clip(0, 50)

# ─────────────────────────────────────────────────────────────────────────────
# CREATE PRICE WITH REALISTIC RELATIONSHIPS:
# ─────────────────────────────────────────────────────────────────────────────
# 
# Price depends on: size (+), bedrooms (+), age (-), plus some randomness

base_price = 100000
price = (base_price + 
         sqft * 150 +           # $150 per square foot
         bedrooms * 25000 -     # $25K per bedroom
         age * 2000 +           # -$2K per year of age
         np.random.normal(0, 30000, n_houses))  # Random variation

# ─────────────────────────────────────────────────────────────────────────────
# CREATE A PANDAS DATAFRAME:
# ─────────────────────────────────────────────────────────────────────────────
# 
# DataFrames are like spreadsheets - rows and columns with labels

housing_df = pd.DataFrame({
    'sqft': sqft,
    'bedrooms': bedrooms,
    'age': age,
    'price': price
})

print("🏠 Generated Housing Dataset:")
print(housing_df.describe().round(2))  # Statistical summary

# ─────────────────────────────────────────────────────────────────────────────
# STEP 2: CREATE MULTI-PANEL SCATTER VISUALIZATION
# ─────────────────────────────────────────────────────────────────────────────

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 1: SCATTER WITH COLOR-CODED THIRD VARIABLE
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# ax.scatter() - Create Scatter Plot
# ─────────────────────────────────────────────────────────────────────────────
# 
# ESSENTIAL PARAMETERS:
#   x, y:    Data for horizontal and vertical positions
#   c:       Values to determine color (array or single color)
#   cmap:    Color map to use when c is numeric
#   s:       Size of markers (single value or array)
#   alpha:   Transparency (0-1)
#   edgecolors: Border color of markers
#
# COLOR MAPS (cmap):
#   'viridis' - Perceptually uniform (default, good for most cases)
#   'plasma'  - Warm colors, perceptually uniform
#   'coolwarm' - Blue to red (good for diverging data)
#   'RdYlGn'  - Red-Yellow-Green (good for good/bad scales)
#   'Blues', 'Reds', 'Greens' - Single color gradients

scatter1 = axes[0].scatter(
    housing_df['sqft'],           # X: Square footage
    housing_df['price']/1000,     # Y: Price in thousands
    c=housing_df['bedrooms'],     # COLOR by number of bedrooms
    cmap='viridis',               # Use viridis colormap
    s=80,                         # Marker size
    alpha=0.7,                    # 70% opaque
    edgecolors='white'            # White border around points
)

axes[0].set_xlabel('Square Footage', fontsize=11)
axes[0].set_ylabel('Price ($K)', fontsize=11)
axes[0].set_title('🏠 Price vs Size (colored by bedrooms)', fontsize=11, fontweight='bold')

# ─────────────────────────────────────────────────────────────────────────────
# plt.colorbar() - Add Color Legend
# ─────────────────────────────────────────────────────────────────────────────
# 
# Syntax: plt.colorbar(mappable, ax=axis)
# 
# Parameters:
#   mappable: The scatter plot object (what was returned by scatter())
#   ax: Which axes to attach the colorbar to

cbar1 = plt.colorbar(scatter1, ax=axes[0])
cbar1.set_label('Bedrooms')  # Label for the colorbar

# ─────────────────────────────────────────────────────────────────────────────
# ADD TREND LINE (Linear Regression):
# ─────────────────────────────────────────────────────────────────────────────

z = np.polyfit(housing_df['sqft'], housing_df['price']/1000, 1)  # Fit line
p = np.poly1d(z)                                                   # Create function
x_line = np.linspace(housing_df['sqft'].min(), housing_df['sqft'].max(), 100)
axes[0].plot(x_line, p(x_line), 'r--', linewidth=2, alpha=0.7, label='Trend')
axes[0].legend()

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 2: DIFFERENT COLORMAP
# ═══════════════════════════════════════════════════════════════════════════════

scatter2 = axes[1].scatter(
    housing_df['age'],            # X: Age
    housing_df['price']/1000,     # Y: Price
    c=housing_df['sqft'],         # COLOR by square footage
    cmap='plasma',                # Different colormap
    s=80, alpha=0.7, edgecolors='white'
)

axes[1].set_xlabel('Age (years)', fontsize=11)
axes[1].set_ylabel('Price ($K)', fontsize=11)
axes[1].set_title('📉 Price vs Age (colored by sqft)', fontsize=11, fontweight='bold')

cbar2 = plt.colorbar(scatter2, ax=axes[1])
cbar2.set_label('Square Feet')

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 3: BUBBLE CHART (Size Represents a Fourth Variable)
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# BUBBLE CHART: Using 's' parameter for variable marker size
# ─────────────────────────────────────────────────────────────────────────────
# 
# When s is an array, each point gets a different size
# s values are in points² (so s=100 is about 10pt diameter)

scatter3 = axes[2].scatter(
    housing_df['sqft'],               # X: Size
    housing_df['price']/1000,         # Y: Price
    s=housing_df['age']*10,           # SIZE by age (multiply to make visible)
    alpha=0.5,                        # More transparent due to overlapping
    c=housing_df['bedrooms'],         # COLOR by bedrooms
    cmap='coolwarm',                  # Blue-to-red colormap
    edgecolors='gray',                # Gray borders
    linewidth=0.5
)

axes[2].set_xlabel('Square Footage', fontsize=11)
axes[2].set_ylabel('Price ($K)', fontsize=11)
axes[2].set_title('🔵 Bubble Chart (size = age)', fontsize=11, fontweight='bold')

cbar3 = plt.colorbar(scatter3, ax=axes[2])
cbar3.set_label('Bedrooms')

plt.tight_layout()
plt.show()

# ─────────────────────────────────────────────────────────────────────────────
# CORRELATION ANALYSIS:
# ─────────────────────────────────────────────────────────────────────────────
# 
# df.corr() calculates correlation coefficient between all numeric columns
# Values range from -1 (perfect negative) to +1 (perfect positive)
# 0 means no linear relationship

print("\n📊 CORRELATION ANALYSIS:")
print("   (How strongly each feature relates to price)")
print("   " + "="*45)
correlations = housing_df[['sqft', 'bedrooms', 'age', 'price']].corr()['price'].sort_values(ascending=False)
for feature, corr in correlations.items():
    if feature != 'price':
        direction = "↑" if corr > 0 else "↓"
        strength = "Strong" if abs(corr) > 0.5 else "Moderate" if abs(corr) > 0.3 else "Weak"
        print(f"   {feature:12} → price: {corr:+.3f} ({strength} {direction})")

print("\n📚 SCATTER PLOT COMMANDS SUMMARY:")
print("   • ax.scatter(x, y, c=values, cmap='name') → Colored scatter")
print("   • ax.scatter(x, y, s=sizes)               → Bubble chart")
print("   • plt.colorbar(scatter, ax=ax)            → Add color legend")
print("   • df.corr()                               → Calculate correlations")

# %% [markdown]
# ## 2.4 Other Essential Matplotlib Charts
#
# ### In this section, we'll learn:
# 1. **Pie Charts & Donut Charts** - Part-to-whole relationships
# 2. **Histograms** - Distribution of continuous data
# 3. **Box Plots** - Distribution summary with outliers

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PIE CHARTS AND DONUT CHARTS - Part-to-Whole Relationships
# ═══════════════════════════════════════════════════════════════════════════════

# ⚠️ IMPORTANT: Pie charts work best with 2-7 categories
# For more categories, use a bar chart instead!

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# ─────────────────────────────────────────────────────────────────────────────
# DATA: Website Traffic Sources
# ─────────────────────────────────────────────────────────────────────────────

sources = ['Organic Search', 'Direct', 'Social Media', 'Email', 'Referral', 'Paid Ads']
traffic = [35, 25, 18, 12, 6, 4]  # Percentages (should sum to 100)
colors = ['#2ecc71', '#3498db', '#e74c3c', '#f39c12', '#9b59b6', '#1abc9c']

# explode: Pull slices away from center
# Use tuple with same length as data
# 0 = no explosion, 0.05 = slight pull, 0.1+ = more dramatic
explode = (0.05, 0, 0, 0, 0, 0)  # Only explode the first slice

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 1: STANDARD PIE CHART
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# ax.pie() - Create Pie Chart
# ─────────────────────────────────────────────────────────────────────────────
# 
# ESSENTIAL PARAMETERS:
#   x:         Data values (sizes of slices)
#   labels:    Text labels for each slice
#   autopct:   Format string for percentage display
#              '%1.1f%%' = 1 decimal place + percent sign
#              '%1.0f%%' = No decimal places
#   
# STYLING PARAMETERS:
#   colors:    List of colors for each slice
#   explode:   Tuple of distances to pull each slice from center
#   startangle: Angle of first slice (0 = right side, 90 = top)
#   shadow:    Add shadow effect (True/False)
#   textprops: Dictionary of text properties (fontsize, color, etc.)
#   
# RETURNS: wedges, texts, autotexts (if autopct is used)

axes[0].pie(traffic,                     # The data
            labels=sources,               # Slice labels
            autopct='%1.1f%%',           # Show percentages
            startangle=90,               # Start from top
            colors=colors,               # Custom colors
            explode=explode,             # Pull out first slice
            shadow=True,                 # Add shadow
            textprops={'fontsize': 10})  # Font settings

axes[0].set_title('🌐 Website Traffic Sources\\n(Pie Chart)', fontsize=12, fontweight='bold')

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 2: DONUT CHART (Modern Alternative)
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# DONUT CHART: Pie chart with a hole in the middle
# ─────────────────────────────────────────────────────────────────────────────
# 
# Created using the 'wedgeprops' parameter
# wedgeprops=dict(width=0.5) creates a ring with 50% of radius as width
# width=1.0 would be a full pie, width=0.3 would be a thin ring

wedges, texts, autotexts = axes[1].pie(
    traffic,
    labels=sources,
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    wedgeprops=dict(width=0.5),  # THIS creates the donut hole!
    pctdistance=0.75             # Where to place percentage (0-1, center to edge)
)

axes[1].set_title('🍩 Website Traffic Sources\\n(Donut Chart)', fontsize=12, fontweight='bold')

# ─────────────────────────────────────────────────────────────────────────────
# ADD CENTER TEXT TO DONUT:
# ─────────────────────────────────────────────────────────────────────────────
# 
# ax.text(0, 0, ...) places text at the center of the axes

axes[1].text(0, 0,                    # Center position
             '100K\\nVisitors',        # Text with newline
             ha='center',              # Horizontal alignment
             va='center',              # Vertical alignment
             fontsize=14, 
             fontweight='bold')

plt.tight_layout()
plt.show()

print("\\n📚 PIE CHART COMMANDS SUMMARY:")
print("   • ax.pie(values, labels=..., autopct='%1.1f%%') → Basic pie")
print("   • ax.pie(..., explode=(0.1, 0, 0))              → Explode slices")
print("   • ax.pie(..., wedgeprops=dict(width=0.5))       → Donut chart")
print("   • ax.text(0, 0, 'text')                         → Center text")

print("\\n⚠️ PIE CHART BEST PRACTICES:")
print("   • Use only for 2-7 categories")
print("   • Percentages should sum to 100%")
print("   • Largest slice at top (startangle=90)")
print("   • Consider donut charts for modern look")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# HISTOGRAMS - Understanding Data Distribution
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Histograms show how data is distributed across a range
# X-axis: Value ranges (bins)
# Y-axis: Count or frequency of values in each bin
#
# Real-World Use Case: Employee Salary Distribution

np.random.seed(42)

# ─────────────────────────────────────────────────────────────────────────────
# GENERATE SALARY DATA FOR DIFFERENT DEPARTMENTS:
# ─────────────────────────────────────────────────────────────────────────────

engineering_salaries = np.random.normal(95000, 15000, 200)  # Mean 95K, std 15K
sales_salaries = np.random.normal(75000, 20000, 150)        # More variable
hr_salaries = np.random.normal(65000, 10000, 50)            # Smaller, less variable

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 1: SIMPLE HISTOGRAM WITH MEAN LINE
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# ax.hist() - Create Histogram
# ─────────────────────────────────────────────────────────────────────────────
# 
# ESSENTIAL PARAMETERS:
#   x:          Data to create histogram from
#   bins:       Number of bins (bars) OR list of bin edges
#               More bins = more detail, fewer = smoother
#   
# STYLING PARAMETERS:
#   color:      Fill color
#   edgecolor:  Border color (use 'white' for clean look)
#   alpha:      Transparency (important for overlapping histograms)
#   label:      For legend
#   
# STATISTICAL PARAMETERS:
#   density:    If True, area under histogram = 1 (probability density)
#               If False (default), shows raw counts
#   cumulative: If True, shows cumulative distribution

axes[0].hist(engineering_salaries,  # The data
             bins=20,                # Number of bins
             color='#3498db',        # Blue fill
             edgecolor='white',      # White borders
             alpha=0.7)              # Slightly transparent

# ─────────────────────────────────────────────────────────────────────────────
# ax.axvline() - Add Vertical Line
# ─────────────────────────────────────────────────────────────────────────────
# 
# Perfect for showing mean, median, or threshold values
# Parameters:
#   x: Position on x-axis
#   color, linestyle, linewidth: Styling
#   label: For legend

mean_salary = engineering_salaries.mean()
axes[0].axvline(mean_salary,                                # X position
                color='red',                                 # Red line
                linestyle='--',                              # Dashed
                linewidth=2, 
                label=f'Mean: ${mean_salary:,.0f}')         # Legend label

axes[0].set_title('👨‍💻 Engineering Salaries', fontsize=11, fontweight='bold')
axes[0].set_xlabel('Salary ($)')
axes[0].set_ylabel('Frequency')
axes[0].legend()
axes[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 2: OVERLAPPING HISTOGRAMS (Comparison)
# ═══════════════════════════════════════════════════════════════════════════════

# When comparing distributions, use alpha for transparency so you can see overlap

axes[1].hist(engineering_salaries, bins=20, alpha=0.6, label='Engineering', color='#3498db')
axes[1].hist(sales_salaries, bins=20, alpha=0.6, label='Sales', color='#e74c3c')
axes[1].hist(hr_salaries, bins=20, alpha=0.6, label='HR', color='#2ecc71')

axes[1].set_title('📊 Salary Distribution by Department', fontsize=11, fontweight='bold')
axes[1].set_xlabel('Salary ($)')
axes[1].set_ylabel('Frequency')
axes[1].legend()
axes[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 3: HISTOGRAM WITH KDE (Kernel Density Estimation)
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# KDE: A smooth curve that estimates the probability density
# ─────────────────────────────────────────────────────────────────────────────

all_salaries = np.concatenate([engineering_salaries, sales_salaries, hr_salaries])

# density=True normalizes so area under histogram = 1
# This allows comparison with the KDE line (which is also normalized)
axes[2].hist(all_salaries, 
             bins=30, 
             density=True,           # Normalize to density (not counts)
             alpha=0.6, 
             color='#9b59b6', 
             edgecolor='white')

# ─────────────────────────────────────────────────────────────────────────────
# scipy.stats.gaussian_kde() - Kernel Density Estimation
# ─────────────────────────────────────────────────────────────────────────────
# 
# Creates a smooth probability density function from the data
# Can be evaluated at any x-value: kde(x) → probability density

from scipy import stats
kde = stats.gaussian_kde(all_salaries)  # Create the KDE from data
x_range = np.linspace(all_salaries.min(), all_salaries.max(), 100)  # Points to evaluate
axes[2].plot(x_range,                    # X values
             kde(x_range),               # Y values from KDE
             'r-',                        # Red solid line
             linewidth=2, 
             label='KDE')

axes[2].set_title('📈 Company-Wide Salary Distribution', fontsize=11, fontweight='bold')
axes[2].set_xlabel('Salary ($)')
axes[2].set_ylabel('Density')  # Note: Density, not Frequency!
axes[2].legend()
axes[2].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

plt.tight_layout()
plt.show()

print("\\n📚 HISTOGRAM COMMANDS SUMMARY:")
print("   • ax.hist(data, bins=20)              → Basic histogram")
print("   • ax.hist(data, density=True)         → Normalized (probability)")
print("   • ax.hist(data, alpha=0.5)            → Transparent (for overlap)")
print("   • ax.axvline(x, ...)                  → Add vertical line")
print("   • stats.gaussian_kde(data)            → Create KDE curve")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BOX PLOTS AND VIOLIN PLOTS - Distribution Summary
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Box plots show the "five-number summary":
# - Minimum (excluding outliers)
# - Q1 (25th percentile) - bottom of box
# - Median (50th percentile) - line in box
# - Q3 (75th percentile) - top of box
# - Maximum (excluding outliers)
# - Outliers shown as individual points
#
# Real-World Use Case: Customer Satisfaction Scores by Region

np.random.seed(42)

# ─────────────────────────────────────────────────────────────────────────────
# GENERATE SATISFACTION SCORES (1-10 scale) FOR DIFFERENT REGIONS:
# ─────────────────────────────────────────────────────────────────────────────

regions = ['North America', 'Europe', 'Asia Pacific', 'Latin America', 'Middle East']

# Each region has different mean and standard deviation
data = {
    'North America': np.random.normal(7.5, 1.2, 100).clip(1, 10),
    'Europe': np.random.normal(8.0, 0.8, 100).clip(1, 10),        # Higher, less variable
    'Asia Pacific': np.random.normal(7.0, 1.5, 100).clip(1, 10),  # More variable
    'Latin America': np.random.normal(6.5, 1.8, 100).clip(1, 10), # Lower, more variable
    'Middle East': np.random.normal(7.2, 1.3, 100).clip(1, 10)
}

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 1: BOX PLOT
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# ax.boxplot() - Create Box Plot
# ─────────────────────────────────────────────────────────────────────────────
# 
# ESSENTIAL PARAMETERS:
#   x:            List of arrays (one per box)
#   labels:       Labels for each box
#   
# STYLING PARAMETERS:
#   patch_artist: If True, boxes are filled (not just lines)
#   vert:         If True (default), vertical boxes; False for horizontal
#   widths:       Width of boxes
#   
# RETURNS: Dictionary with 'boxes', 'whiskers', 'caps', 'medians', 'fliers'

# Convert dictionary values to list (order matters!)
box_data = [data[r] for r in regions]

bp1 = axes[0].boxplot(box_data,          # List of arrays
                      labels=regions,     # X-axis labels
                      patch_artist=True)  # Fill boxes with color

# ─────────────────────────────────────────────────────────────────────────────
# COLORING BOX PLOT BOXES:
# ─────────────────────────────────────────────────────────────────────────────
# 
# boxplot returns a dictionary - access 'boxes' to color them

colors = ['#3498db', '#e74c3c', '#2ecc71', '#f39c12', '#9b59b6']

for patch, color in zip(bp1['boxes'], colors):
    patch.set_facecolor(color)   # Fill color
    patch.set_alpha(0.7)         # Transparency

axes[0].set_title('📦 Customer Satisfaction by Region\\n(Box Plot)', fontsize=11, fontweight='bold')
axes[0].set_ylabel('Satisfaction Score (1-10)')
axes[0].set_xticklabels(regions, rotation=30, ha='right')

# ─────────────────────────────────────────────────────────────────────────────
# ax.axhline() - Add Horizontal Line
# ─────────────────────────────────────────────────────────────────────────────

axes[0].axhline(y=7,                    # Y position
                color='green',           # Green line
                linestyle='--',          # Dashed
                alpha=0.7, 
                label='Target (7.0)')
axes[0].legend()

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 2: VIOLIN PLOT (Shows distribution shape)
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# ax.violinplot() - Create Violin Plot
# ─────────────────────────────────────────────────────────────────────────────
# 
# Violin plots combine box plot info with KDE (distribution shape)
# Wider parts = more data points at that value
#
# PARAMETERS:
#   dataset:      List of arrays
#   showmeans:    Show mean as horizontal line
#   showmedians:  Show median as horizontal line
#   showextrema:  Show min/max lines

parts = axes[1].violinplot(box_data,       # Same data as box plot
                           showmeans=True,  # Show mean line
                           showmedians=True) # Show median line

# ─────────────────────────────────────────────────────────────────────────────
# COLORING VIOLIN PLOTS:
# ─────────────────────────────────────────────────────────────────────────────
# 
# violinplot returns a dictionary with 'bodies' (the violin shapes)

for i, pc in enumerate(parts['bodies']):
    pc.set_facecolor(colors[i])
    pc.set_alpha(0.7)

axes[1].set_title('🎻 Customer Satisfaction by Region\\n(Violin Plot)', fontsize=11, fontweight='bold')
axes[1].set_ylabel('Satisfaction Score (1-10)')
axes[1].set_xticks(range(1, len(regions) + 1))  # Positions 1, 2, 3, 4, 5
axes[1].set_xticklabels(regions, rotation=30, ha='right')

plt.tight_layout()
plt.show()

# ─────────────────────────────────────────────────────────────────────────────
# SUMMARY STATISTICS:
# ─────────────────────────────────────────────────────────────────────────────

print("\\n📊 Summary Statistics by Region:")
print("   " + "="*60)
print(f"   {'Region':<18} {'Mean':>8} {'Median':>8} {'Std Dev':>8} {'Min':>6} {'Max':>6}")
print("   " + "-"*60)
for region in regions:
    d = data[region]
    print(f"   {region:<18} {np.mean(d):>8.2f} {np.median(d):>8.2f} {np.std(d):>8.2f} {np.min(d):>6.2f} {np.max(d):>6.2f}")

print("\\n📚 BOX/VIOLIN PLOT COMMANDS SUMMARY:")
print("   • ax.boxplot(data_list, labels=...)           → Box plot")
print("   • ax.boxplot(..., patch_artist=True)          → Filled boxes")
print("   • ax.violinplot(data_list, showmeans=True)    → Violin plot")
print("   • ax.axhline(y, ...)                          → Horizontal reference line")

# %% [markdown]
# ## 2.5 Matplotlib Subplots and Layouts

# %%
# Creating Complex Layouts with GridSpec
from matplotlib.gridspec import GridSpec

# Sample data for dashboard
np.random.seed(42)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
sales = [120, 150, 180, 140, 200, 220]
customers = [800, 950, 1100, 900, 1300, 1400]
categories = ['Product A', 'Product B', 'Product C', 'Product D']
cat_sales = [35, 30, 20, 15]

# Create figure with custom layout
fig = plt.figure(figsize=(14, 10))
gs = GridSpec(3, 3, figure=fig, hspace=0.3, wspace=0.3)

# Large plot spanning 2 columns
ax1 = fig.add_subplot(gs[0, :2])
ax1.plot(months, sales, marker='o', linewidth=2, markersize=10, color='#3498db')
ax1.fill_between(months, sales, alpha=0.3, color='#3498db')
ax1.set_title('📈 Monthly Sales Trend', fontweight='bold')
ax1.set_ylabel('Sales ($K)')

# Small pie chart
ax2 = fig.add_subplot(gs[0, 2])
ax2.pie(cat_sales, labels=categories, autopct='%1.0f%%', colors=['#e74c3c', '#3498db', '#2ecc71', '#f39c12'])
ax2.set_title('🥧 Sales by Product', fontweight='bold')

# Bar chart spanning full width
ax3 = fig.add_subplot(gs[1, :])
x = np.arange(len(months))
width = 0.35
ax3.bar(x - width/2, sales, width, label='Sales ($K)', color='#3498db')
ax3.bar(x + width/2, [c/10 for c in customers], width, label='Customers (×10)', color='#e74c3c')
ax3.set_xticks(x)
ax3.set_xticklabels(months)
ax3.legend()
ax3.set_title('📊 Sales vs Customer Count', fontweight='bold')

# Three small plots at the bottom
ax4 = fig.add_subplot(gs[2, 0])
ax4.hist(np.random.normal(100, 20, 500), bins=20, color='#9b59b6', edgecolor='white')
ax4.set_title('📉 Order Value Distribution', fontweight='bold')

ax5 = fig.add_subplot(gs[2, 1])
ax5.scatter(np.random.rand(50)*100, np.random.rand(50)*100, c=np.random.rand(50), cmap='viridis', s=100, alpha=0.6)
ax5.set_title('🔵 Customer Segments', fontweight='bold')

ax6 = fig.add_subplot(gs[2, 2])
ax6.barh(['Excellent', 'Good', 'Average', 'Poor'], [45, 35, 15, 5], color=['#2ecc71', '#3498db', '#f39c12', '#e74c3c'])
ax6.set_title('⭐ Customer Ratings', fontweight='bold')

fig.suptitle('🎯 Sales Dashboard - Q1 2025', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # 3. Seaborn Overview
#
# **Seaborn** is built on top of Matplotlib and provides a high-level interface for creating attractive statistical graphics. It integrates closely with Pandas DataFrames.
#
# ## Key Advantages of Seaborn:
#
# | Feature | Description |
# |---------|-------------|
# | **Beautiful defaults** | Attractive plots with minimal code |
# | **Built-in themes** | Easy style switching with `sns.set_theme()` |
# | **DataFrame integration** | Pass column names directly |
# | **Statistical functions** | Automatic aggregation, confidence intervals |
# | **Automatic handling** | Smart defaults for categorical data |
#
# ## Seaborn Plot Categories:
#
# 1. **Relational**: `scatterplot`, `lineplot`, `relplot`
# 2. **Distribution**: `histplot`, `kdeplot`, `boxplot`, `violinplot`
# 3. **Categorical**: `barplot`, `countplot`, `stripplot`, `swarmplot`
# 4. **Matrix**: `heatmap`, `clustermap`
# 5. **Regression**: `regplot`, `lmplot`

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# LOADING SEABORN'S BUILT-IN DATASETS
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.load_dataset() - Load Famous Datasets
# ─────────────────────────────────────────────────────────────────────────────
# 
# Seaborn includes several classic datasets for learning:
#   'tips'     - Restaurant tips data (total bill, tip, day, time, etc.)
#   'iris'     - Flower measurements (famous ML dataset)
#   'titanic'  - Titanic passenger survival data
#   'penguins' - Penguin species measurements
#   'flights'  - Monthly airline passenger counts
#   'planets'  - Exoplanet discoveries
#   'diamonds' - Diamond prices and characteristics
#
# These are perfect for practicing visualization!

tips = sns.load_dataset('tips')      # Restaurant data
iris = sns.load_dataset('iris')      # Flower measurements
titanic = sns.load_dataset('titanic')  # Passenger survival

print("=" * 70)
print("📊 SEABORN BUILT-IN DATASETS LOADED")
print("=" * 70)

print(f"\\n1️⃣ Tips Dataset: {tips.shape[0]} records, {tips.shape[1]} columns")
print(f"   Columns: {list(tips.columns)}")
print(tips.head(3).to_string(index=False))

print(f"\\n2️⃣ Iris Dataset: {iris.shape[0]} records, {iris.shape[1]} columns")
print(f"   Columns: {list(iris.columns)}")
print(iris.head(3).to_string(index=False))

print(f"\\n3️⃣ Titanic Dataset: {titanic.shape[0]} records, {titanic.shape[1]} columns")
print(f"   Columns: {list(titanic.columns)}")

# %% [markdown]
# ## 3.1 Seaborn Distribution Plots
#
# ### Key Distribution Functions:
#
# | Function | Purpose | When to Use |
# |----------|---------|-------------|
# | `sns.histplot()` | Histogram with optional KDE | Single variable distribution |
# | `sns.kdeplot()` | Smooth density curve | Compare distributions |
# | `sns.boxplot()` | Box plot by category | Compare medians, see outliers |
# | `sns.violinplot()` | Distribution shape | Detailed distribution comparison |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# SEABORN DISTRIBUTION PLOTS - Detailed Tutorial
# ═══════════════════════════════════════════════════════════════════════════════

fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 1: sns.histplot() - Histogram with KDE
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.histplot() - Create Histogram
# ─────────────────────────────────────────────────────────────────────────────
# 
# MAJOR ADVANTAGE OVER MATPLOTLIB:
#   - Direct DataFrame column reference
#   - Automatic KDE overlay option
#   - Better default styling
#
# PARAMETERS:
#   data:     DataFrame (optional, allows column names)
#   x or y:   Column name or array
#   kde:      Add KDE curve overlay (True/False)
#   bins:     Number of bins (or 'auto')
#   stat:     'count', 'density', 'probability', 'percent'
#   hue:      Column to color-code by (automatic legend!)
#   multiple: How to handle multiple groups: 'layer', 'stack', 'dodge', 'fill'
#   ax:       Which matplotlib axes to plot on

sns.histplot(tips['total_bill'],  # Can also use: data=tips, x='total_bill'
             kde=True,            # Add smooth KDE curve on top
             ax=axes[0, 0],       # Which subplot
             color='#3498db')     # Custom color

axes[0, 0].set_title('📊 Distribution of Total Bills', fontweight='bold')
axes[0, 0].set_xlabel('Total Bill ($)')

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 2: sns.kdeplot() - KDE by Category
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.kdeplot() - Kernel Density Estimation
# ─────────────────────────────────────────────────────────────────────────────
# 
# GREAT FOR: Comparing distributions between groups
#
# PARAMETERS:
#   data:     DataFrame
#   x:        Column for x-axis
#   hue:      Column to split by (creates multiple curves)
#   fill:     Fill under the curve (True/False)
#   common_norm: If False, each group normalized separately
#   palette:  Color palette name

sns.kdeplot(data=tips,            # The DataFrame
            x='total_bill',       # Column to plot
            hue='time',           # Split by lunch vs dinner
            ax=axes[0, 1],        # Which subplot
            fill=True,            # Shade under curves
            alpha=0.5)            # Transparency for overlap

axes[0, 1].set_title('📈 Bill Distribution: Lunch vs Dinner', fontweight='bold')
axes[0, 1].set_xlabel('Total Bill ($)')

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 3: sns.boxplot() with Multiple Categories
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.boxplot() - Box Plot with Categorical Grouping
# ─────────────────────────────────────────────────────────────────────────────
# 
# MAJOR ADVANTAGES:
#   - Automatic grouping by category
#   - 'hue' parameter for additional grouping
#   - Beautiful default colors
#
# PARAMETERS:
#   data:     DataFrame
#   x:        Categorical column for x-axis
#   y:        Numeric column for y-axis
#   hue:      Additional categorical grouping (side by side)
#   palette:  Color palette ('Set2', 'deep', 'muted', 'bright', etc.)
#   dodge:    If True (default), grouped boxes are side by side

sns.boxplot(data=tips,           # The DataFrame
            x='day',             # Category for x-axis
            y='total_bill',      # Values for y-axis
            hue='sex',           # Additional grouping
            ax=axes[1, 0],       # Which subplot
            palette='Set2')      # Color palette

axes[1, 0].set_title('📦 Bills by Day and Gender', fontweight='bold')
axes[1, 0].set_xlabel('Day of Week')
axes[1, 0].set_ylabel('Total Bill ($)')

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 4: sns.violinplot() with Split
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.violinplot() - Violin Plot
# ─────────────────────────────────────────────────────────────────────────────
# 
# SPECIAL PARAMETER:
#   split: If True and hue has 2 values, shows half violin for each
#          This makes comparison MUCH easier!

sns.violinplot(data=tips,
               x='day',
               y='tip',
               hue='smoker',       # Split by smoker status
               split=True,         # Half violin for each hue value
               ax=axes[1, 1],
               palette='muted')    # Muted color palette

axes[1, 1].set_title('🎻 Tip Distribution: Smokers vs Non-Smokers', fontweight='bold')
axes[1, 1].set_xlabel('Day of Week')
axes[1, 1].set_ylabel('Tip ($)')

plt.tight_layout()
plt.show()

print("\\n📚 SEABORN DISTRIBUTION COMMANDS SUMMARY:")
print("   • sns.histplot(data, x='col', kde=True)       → Histogram + KDE")
print("   • sns.kdeplot(data, x='col', hue='cat')       → Density curves by group")
print("   • sns.boxplot(data, x='cat', y='val', hue=...)→ Grouped box plots")
print("   • sns.violinplot(..., split=True)             → Split violin for comparison")

# %% [markdown]
# ## 3.2 Seaborn Relationship Plots
#
# ### Key Relationship Functions:
#
# | Function | Purpose | When to Use |
# |----------|---------|-------------|
# | `sns.scatterplot()` | Scatter with categories | Relationships with grouping |
# | `sns.regplot()` | Scatter + regression line | Show correlation |
# | `sns.pairplot()` | All pairwise relationships | Exploratory analysis |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# SEABORN RELATIONSHIP PLOTS - Detailed Tutorial
# ═══════════════════════════════════════════════════════════════════════════════

fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 1: sns.regplot() - Scatter with Regression Line
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.regplot() - Regression Plot
# ─────────────────────────────────────────────────────────────────────────────
# 
# Automatically adds:
#   - Scatter points
#   - Regression line (best fit)
#   - Confidence interval (shaded area)
#
# PARAMETERS:
#   data:         DataFrame
#   x, y:         Column names
#   scatter_kws:  Dict of kwargs for scatter points
#   line_kws:     Dict of kwargs for regression line
#   ci:           Confidence interval (0-100, or None to hide)
#   order:        Polynomial order (1=linear, 2=quadratic, etc.)

sns.regplot(data=tips,
            x='total_bill',
            y='tip',
            ax=axes[0, 0],
            scatter_kws={'alpha': 0.6},      # Make points semi-transparent
            line_kws={'color': 'red'})       # Red regression line

axes[0, 0].set_title('📈 Tip vs Total Bill (with regression)', fontweight='bold')

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 2: sns.scatterplot() - Multi-dimensional Scatter
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.scatterplot() - Advanced Scatter Plot
# ─────────────────────────────────────────────────────────────────────────────
# 
# POWERFUL FEATURES:
#   hue:    Color points by category
#   style:  Different markers by category  
#   size:   Size points by numeric value
#
# This lets you show 5 DIMENSIONS in one plot!
#   1. X position
#   2. Y position  
#   3. Color (hue)
#   4. Marker shape (style)
#   5. Marker size (size)

sns.scatterplot(data=tips,
                x='total_bill',
                y='tip',
                hue='time',         # Color by lunch/dinner
                style='smoker',     # Different markers for smoker/non-smoker
                size='size',        # Point size by party size
                sizes=(50, 200),    # Range of point sizes
                ax=axes[0, 1],
                palette='deep')     # Color palette

axes[0, 1].set_title('🔵 Multi-dimensional Scatter Plot', fontweight='bold')

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 3: Scatter with Species Categories (Iris Dataset)
# ═══════════════════════════════════════════════════════════════════════════════

sns.scatterplot(data=iris,
                x='sepal_length',
                y='sepal_width',
                hue='species',      # Color by species
                ax=axes[1, 0],
                palette='viridis',
                s=80,               # Fixed point size
                alpha=0.7)

axes[1, 0].set_title('🌸 Iris: Sepal Length vs Width', fontweight='bold')

# ═══════════════════════════════════════════════════════════════════════════════
# PLOT 4: sns.stripplot() - Categorical Scatter
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.stripplot() - Jittered Scatter by Category
# ─────────────────────────────────────────────────────────────────────────────
# 
# Shows individual data points for each category
# Points are "jittered" (randomly spread horizontally) to avoid overlap
#
# PARAMETER:
#   dodge: If True and hue is used, separates groups side-by-side

sns.stripplot(data=tips,
              x='day',
              y='total_bill',
              hue='sex',
              dodge=True,           # Separate male/female
              ax=axes[1, 1],
              alpha=0.7,
              palette='Set1')

axes[1, 1].set_title('📍 Individual Bills by Day and Gender', fontweight='bold')

plt.tight_layout()
plt.show()

print("\\n📚 SEABORN RELATIONSHIP COMMANDS SUMMARY:")
print("   • sns.regplot(data, x, y)                    → Scatter + regression")
print("   • sns.scatterplot(..., hue, style, size)    → Multi-dimensional")
print("   • sns.stripplot(data, x, y, hue, dodge=True) → Categorical scatter")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# sns.pairplot() - Visualize ALL Pairwise Relationships
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.pairplot() - The Ultimate Exploratory Tool
# ─────────────────────────────────────────────────────────────────────────────
# 
# Creates a grid showing:
#   - Diagonal: Distribution of each variable (histogram or KDE)
#   - Off-diagonal: Scatter plot of each pair of variables
#
# EXTREMELY USEFUL for:
#   - Exploring a new dataset
#   - Finding correlations between variables
#   - Identifying clusters or groups
#
# PARAMETERS:
#   data:        DataFrame
#   hue:         Column to color by
#   diag_kind:   'hist' or 'kde' for diagonal plots
#   kind:        'scatter', 'kde', or 'reg' for off-diagonal
#   corner:      If True, only show lower triangle (less redundant)
#   plot_kws:    Dict of kwargs for scatter plots
#   palette:     Color palette

g = sns.pairplot(iris,
                 hue='species',               # Color by species
                 diag_kind='kde',             # KDE on diagonal (instead of histogram)
                 plot_kws={'alpha': 0.6,      # Scatter plot settings
                          's': 80, 
                          'edgecolor': 'white'},
                 palette='husl')

# Add overall title
g.fig.suptitle('🌺 Iris Dataset: Pairwise Feature Relationships', 
               y=1.02,                        # y > 1 places above the figure
               fontsize=14, 
               fontweight='bold')

plt.show()

print("\\n💡 INSIGHTS FROM PAIR PLOT:")
print("   • Setosa (green) is clearly separated from others in most dimensions")
print("   • Versicolor and Virginica overlap but are distinguishable")
print("   • Petal length & width are strongly correlated (diagonal pattern)")
print("   • This is why Iris is a classic machine learning dataset!")

print("\\n📚 PAIRPLOT COMMAND:")
print("   sns.pairplot(data, hue='category', diag_kind='kde', palette='name')")

# %% [markdown]
# ## 3.4 Heatmaps and Correlation Matrices
#
# ### 🏥 Real-World Use Case: Hospital Performance Metrics
#
# Heatmaps are perfect for:
# - **Correlation matrices**: See relationships between all variables
# - **Performance dashboards**: Compare metrics across categories
# - **Time-based patterns**: Show activity by hour/day

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# sns.heatmap() - Visualize Matrix Data
# ═══════════════════════════════════════════════════════════════════════════════

np.random.seed(42)

# ─────────────────────────────────────────────────────────────────────────────
# CREATE SAMPLE HOSPITAL PERFORMANCE DATA:
# ─────────────────────────────────────────────────────────────────────────────

departments = ['Cardiology', 'Neurology', 'Orthopedics', 'Pediatrics', 'Oncology', 'Emergency']
metrics = ['Patient Satisfaction', 'Wait Time Score', 'Treatment Success', 'Staff Efficiency', 'Cost Efficiency']

# Generate random performance scores (60-100)
performance_data = np.random.randint(60, 100, size=(len(departments), len(metrics)))

# Create DataFrame with labels
performance_df = pd.DataFrame(performance_data, 
                              index=departments, 
                              columns=metrics)

print("🏥 Hospital Performance Scores:")
print(performance_df)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 1: BASIC HEATMAP
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# sns.heatmap() - Create Heatmap
# ─────────────────────────────────────────────────────────────────────────────
# 
# ESSENTIAL PARAMETERS:
#   data:       2D array or DataFrame
#   annot:      Show values in cells (True/False or array)
#   fmt:        Format string for annotations ('d' = integer, '.2f' = 2 decimals)
#   cmap:       Color map (see list below)
#   
# STYLING PARAMETERS:
#   linewidths: Width of lines between cells
#   linecolor:  Color of cell borders
#   square:     Make cells square (True/False)
#   cbar_kws:   Dict of colorbar settings
#   vmin, vmax: Min/max values for color scale
#   center:     Value to center colormap on (for diverging)
#
# POPULAR COLORMAPS:
#   Sequential:  'Blues', 'Reds', 'Greens', 'YlOrRd', 'viridis'
#   Diverging:   'RdYlGn' (Red-Yellow-Green), 'coolwarm', 'RdBu'
#   For performance: 'RdYlGn' (red=bad, green=good)

sns.heatmap(performance_df,
            annot=True,               # Show values in cells
            fmt='d',                  # Format as integers
            cmap='RdYlGn',           # Red-Yellow-Green colormap
            ax=axes[0],
            linewidths=0.5,          # White grid lines between cells
            cbar_kws={'label': 'Score'})  # Colorbar label

axes[0].set_title('🏥 Hospital Department Performance Scores', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Performance Metrics')
axes[0].set_ylabel('Departments')

# ═══════════════════════════════════════════════════════════════════════════════
# SUBPLOT 2: CORRELATION HEATMAP
# ═══════════════════════════════════════════════════════════════════════════════

# ─────────────────────────────────────────────────────────────────────────────
# CALCULATING CORRELATION MATRIX:
# ─────────────────────────────────────────────────────────────────────────────
# 
# df.corr() calculates Pearson correlation between all numeric columns
# Values range from -1 to +1:
#   +1 = Perfect positive correlation
#    0 = No linear relationship
#   -1 = Perfect negative correlation

tips_numeric = tips[['total_bill', 'tip', 'size']].copy()
tips_numeric['tip_pct'] = tips['tip'] / tips['total_bill'] * 100  # Add calculated column
correlation = tips_numeric.corr()

print("\\n🔗 Correlation Matrix:")
print(correlation.round(3))

# ─────────────────────────────────────────────────────────────────────────────
# MASKING THE UPPER TRIANGLE:
# ─────────────────────────────────────────────────────────────────────────────
# 
# Correlation matrices are symmetric, so upper triangle is redundant
# We create a boolean mask to hide it
#
# np.triu() creates upper triangle matrix
# np.ones_like() creates array of same shape filled with 1s
# dtype=bool converts to True/False

mask = np.triu(np.ones_like(correlation, dtype=bool))

sns.heatmap(correlation,
            annot=True,               # Show correlation values
            fmt='.2f',                # 2 decimal places
            cmap='coolwarm',          # Blue-Red diverging colormap
            ax=axes[1],
            mask=mask,                # Hide upper triangle
            center=0,                 # Center colormap at 0
            linewidths=0.5,
            square=True,              # Square cells
            cbar_kws={'label': 'Correlation'})

axes[1].set_title('🔗 Correlation Matrix: Tips Dataset', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

print("\\n📚 HEATMAP COMMANDS SUMMARY:")
print("   • sns.heatmap(data, annot=True, fmt='d')     → Basic heatmap with values")
print("   • sns.heatmap(..., cmap='RdYlGn')            → Red-Yellow-Green colors")
print("   • sns.heatmap(..., mask=upper_triangle)      → Hide redundant data")
print("   • sns.heatmap(..., center=0)                 → Center diverging colormap")

# %% [markdown]
# ## 3.4 Heatmaps and Correlation Matrices
#
# ### 🏥 Real-World Use Case: Hospital Performance Metrics
#
# Heatmaps are powerful for visualizing **matrix data** where values are represented as colors.
#
# ## Key Functions
#
# | Function | Purpose |
# |----------|---------|
# | `sns.heatmap()` | Create a 2D colored matrix |
# | `sns.clustermap()` | Heatmap with hierarchical clustering |
# | `df.corr()` | Calculate correlation matrix |
# | `np.triu()` | Create upper triangle mask |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# HOSPITAL PERFORMANCE HEATMAP & CORRELATION MATRIX
# ═══════════════════════════════════════════════════════════════════════════════

# ─── STEP 1: Create Sample Hospital Performance Data ────────────────────────────
# We'll create a DataFrame showing how each department scores on different metrics

np.random.seed(42)  # For reproducible results

# Define departments and metrics (our row and column labels)
departments = ['Cardiology', 'Neurology', 'Orthopedics', 'Pediatrics', 'Oncology', 'Emergency']
metrics = ['Patient Satisfaction', 'Wait Time Score', 'Treatment Success', 'Staff Efficiency', 'Cost Efficiency']

# Generate random performance scores (0-100 scale)
# np.random.randint(low, high, size=(rows, cols)) creates a 2D array
performance_data = np.random.randint(60, 100, size=(len(departments), len(metrics)))

# Create DataFrame with meaningful index (rows) and columns
#   index=departments → row labels
#   columns=metrics → column labels
performance_df = pd.DataFrame(performance_data, index=departments, columns=metrics)

print("📊 Hospital Performance DataFrame:")
print(performance_df)
print()

# ─── STEP 2: Create Side-by-Side Heatmaps ───────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ─── HEATMAP 1: Performance Scores ──────────────────────────────────────────────
# sns.heatmap() creates a color-coded matrix
#
# PARAMETERS:
#   data        → DataFrame or 2D array
#   annot       → True = show values in each cell
#   fmt         → Format for annotations: 'd'=integer, '.2f'=2 decimals
#   cmap        → Colormap: 'RdYlGn'=Red-Yellow-Green (bad to good)
#   ax          → Which axes to draw on
#   linewidths  → Width of lines between cells (grid)
#   cbar_kws    → Dictionary for colorbar settings

sns.heatmap(performance_df,           # Our DataFrame
            annot=True,               # Show numbers in cells
            fmt='d',                  # 'd' = display as integers
            cmap='RdYlGn',            # Red=low, Yellow=medium, Green=high
            ax=axes[0],               # Draw on left subplot
            linewidths=0.5,           # Add thin grid lines
            cbar_kws={'label': 'Score'})  # Label the colorbar

axes[0].set_title('🏥 Hospital Department Performance Scores', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Performance Metrics')
axes[0].set_ylabel('Departments')

# ─── HEATMAP 2: Correlation Matrix ──────────────────────────────────────────────
# Correlation shows how variables relate: +1 = perfect positive, -1 = perfect negative, 0 = no relation

# Prepare numeric data for correlation
tips_numeric = tips[['total_bill', 'tip', 'size']].copy()  # Select numeric columns
tips_numeric['tip_pct'] = tips['tip'] / tips['total_bill'] * 100  # Add calculated column

# df.corr() calculates correlation between all pairs of columns
# Returns a symmetric matrix (tip vs total_bill = total_bill vs tip)
correlation = tips_numeric.corr()

print("📊 Correlation Matrix:")
print(correlation)
print()

# ─── Creating a Triangle Mask (to hide redundant upper half) ────────────────────
# np.triu() = "tri"angle "u"pper - creates array with True in upper triangle
# np.ones_like() creates array of 1s (True) matching our correlation shape
mask = np.triu(np.ones_like(correlation, dtype=bool))

# The mask hides cells where mask=True (upper triangle + diagonal)

sns.heatmap(correlation,          # Correlation DataFrame
            annot=True,           # Show correlation values
            fmt='.2f',            # Display with 2 decimal places
            cmap='coolwarm',      # Blue=negative, White=0, Red=positive
            ax=axes[1],           # Draw on right subplot
            mask=mask,            # Hide upper triangle
            center=0,             # Center colormap at 0 (neutral)
            linewidths=0.5,       # Grid lines
            square=True,          # Make cells square
            cbar_kws={'label': 'Correlation'})

axes[1].set_title('🔗 Correlation Matrix: Tips Dataset', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 COMMAND SUMMARY - HEATMAPS
# ═══════════════════════════════════════════════════════════════════════════════
# sns.heatmap(data, ...)       → Create color-coded matrix visualization
#   annot=True                 → Display values in cells
#   fmt='d' or '.2f'          → Format: 'd'=integer, '.2f'=2 decimals
#   cmap='RdYlGn'             → Colormap (try: 'coolwarm', 'viridis', 'Blues')
#   linewidths=0.5            → Width of cell borders
#   mask=array                → Boolean array - True cells are hidden
#   center=0                  → Value that maps to center of colormap
#   square=True               → Force square cells
#   cbar_kws={'label': '...'} → Customize colorbar
#
# df.corr()                   → Calculate pairwise correlations
# np.triu(matrix)             → Get upper triangle of matrix
# np.ones_like(df, dtype=bool)→ Create boolean array matching df shape
# ═══════════════════════════════════════════════════════════════════════════════

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CLUSTERED HEATMAP - CUSTOMER SEGMENTATION
# ═══════════════════════════════════════════════════════════════════════════════
# sns.clustermap() adds HIERARCHICAL CLUSTERING to a heatmap
# It automatically groups similar rows AND columns together
# Perfect for: customer segmentation, gene expression, feature analysis

np.random.seed(42)

# ─── STEP 1: Create Customer Behavior Data ──────────────────────────────────────
n_customers = 20

# Define behavioral metrics we track for each customer
behaviors = ['Purchase Frequency', 'Avg Order Value', 'Website Visits', 
             'Email Opens', 'Support Tickets', 'Return Rate']

# Create formatted customer IDs using f-strings
# f'Customer_{i:03d}' → 'Customer_001', 'Customer_002', etc.
# :03d means: 3 digits, zero-padded
customer_ids = [f'Customer_{i:03d}' for i in range(1, n_customers + 1)]

# Generate random behavioral scores (0-100 scale)
# np.random.rand() returns values between 0 and 1
# Multiply by 100 to get scores from 0-100
behavior_data = np.random.rand(n_customers, len(behaviors)) * 100
behavior_df = pd.DataFrame(behavior_data, index=customer_ids, columns=behaviors)

print("📊 Customer Behavior Data (first 5 rows):")
print(behavior_df.head())
print()

# ─── STEP 2: Create Clustered Heatmap ───────────────────────────────────────────
# sns.clustermap() automatically:
#   1. Calculates distances between rows (customers)
#   2. Calculates distances between columns (behaviors)
#   3. Performs hierarchical clustering on both
#   4. Reorders rows and columns to group similar items
#   5. Displays dendrograms (tree diagrams) showing clusters
#
# PARAMETERS:
#   data            → DataFrame with numeric values
#   cmap            → Colormap for colors
#   figsize         → Figure size (width, height)
#   standard_scale  → Normalize data: 0=by row, 1=by column
#   linewidths      → Grid line width
#   cbar_kws        → Colorbar settings dictionary

g = sns.clustermap(behavior_df,                    # Our DataFrame
                   cmap='viridis',                  # Yellow-green-blue colormap
                   figsize=(12, 10),                # Larger figure for readability
                   standard_scale=1,                # Normalize by column (behavior)
                   linewidths=0.5,                  # Add grid
                   cbar_kws={'label': 'Standardized Score'})

# Add title above the figure
# y=1.02 positions it slightly above the plot
g.fig.suptitle('👥 Customer Segmentation: Behavioral Clustering', 
               fontsize=14, fontweight='bold', y=1.02)

plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 INTERPRETING THE CLUSTERMAP
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 HOW TO READ A CLUSTERMAP:")
print("   • LEFT DENDROGRAM: Shows how customers are grouped by similarity")
print("   • TOP DENDROGRAM: Shows how behaviors are related")
print("   • CLOSER BRANCHES = More similar items")
print("   • Colors show standardized scores (after normalization)")
print()
print("💡 BUSINESS INSIGHT: Clusters reveal customer segments!")
print("   • High-value customers: High purchase frequency + order value")
print("   • At-risk customers: High support tickets + return rate")
print("   • Engaged customers: High website visits + email opens")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 COMMAND SUMMARY - CLUSTERMAP
# ═══════════════════════════════════════════════════════════════════════════════
# sns.clustermap(data, ...)    → Heatmap with hierarchical clustering
#   cmap='viridis'            → Colormap
#   figsize=(12, 10)          → Figure dimensions
#   standard_scale=0          → Normalize rows (compare across columns)
#   standard_scale=1          → Normalize columns (compare across rows)
#   method='average'          → Linkage method: 'single', 'complete', 'average'
#   metric='euclidean'        → Distance metric: 'euclidean', 'correlation'
#   row_cluster=True          → Whether to cluster rows
#   col_cluster=True          → Whether to cluster columns
#   dendrogram_ratio=(.1,.2)  → Size of dendrograms (row, col)
#   colors=...                → Add color bars for categories
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ## 3.5 FacetGrid - Multi-plot Layouts
#
# FacetGrid creates a **grid of plots** based on categorical variables in your data.
#
# ### 🤔 When to Use FacetGrid?
# - When you want to compare the same relationship across different categories
# - When you have categorical variables that split your data into meaningful groups
# - When a single plot would be too cluttered with all data combined
#
# ### Key Functions
#
# | Function | Purpose |
# |----------|---------|
# | `sns.FacetGrid(data, col=, row=)` | Create the grid structure |
# | `g.map()` | Apply a plot function to each facet |
# | `g.map_dataframe()` | Apply function with full DataFrame |
# | `g.add_legend()` | Add a shared legend |
# | `g.fig.suptitle()` | Add overall title |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# FACETGRID EXAMPLE 1: SCATTER PLOTS BY CATEGORIES
# ═══════════════════════════════════════════════════════════════════════════════
# This creates a 2×2 grid: rows = smoker status, columns = meal time

# ─── STEP 1: Create the FacetGrid Structure ─────────────────────────────────────
# sns.FacetGrid() sets up the grid WITHOUT plotting data yet
#
# PARAMETERS:
#   data   → DataFrame to use
#   col    → Variable for COLUMNS (creates left/right facets)
#   row    → Variable for ROWS (creates top/bottom facets)
#   height → Height of each facet in inches
#   aspect → Width/height ratio (1.2 = slightly wider than tall)

g = sns.FacetGrid(tips,           # Our DataFrame
                  col='time',      # Columns split by: Lunch vs Dinner
                  row='smoker',    # Rows split by: Yes vs No
                  height=4,        # Each subplot is 4 inches tall
                  aspect=1.2)      # Each subplot is 4.8 inches wide

# ─── STEP 2: Map a Plot Function to Each Facet ──────────────────────────────────
# g.map_dataframe() applies a plotting function to each subset of data
#
# PARAMETERS:
#   func     → The plotting function (sns.scatterplot, sns.histplot, etc.)
#   x, y     → Column names for axes
#   hue      → Column name for color coding WITHIN each facet
#   palette  → Color palette for hue categories
#   alpha    → Transparency (0=invisible, 1=solid)

g.map_dataframe(sns.scatterplot,  # Apply scatterplot to each facet
                x='total_bill',    # X-axis: bill amount
                y='tip',           # Y-axis: tip amount
                hue='day',         # Color by day of week
                palette='deep',    # Color scheme
                alpha=0.7)         # Slight transparency

# ─── STEP 3: Add Legend and Title ───────────────────────────────────────────────
# g.add_legend() creates a shared legend for all facets
g.add_legend(title='Day')

# g.fig accesses the underlying matplotlib Figure
# y=1.02 positions title slightly above the grid
g.fig.suptitle('💰 Tips vs Bills: Segmented Analysis', y=1.02, fontsize=14, fontweight='bold')

plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 UNDERSTANDING THE RESULT
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 This grid shows 4 separate scatter plots:")
print("   • Top-left: Non-smokers at Lunch")
print("   • Top-right: Non-smokers at Dinner")
print("   • Bottom-left: Smokers at Lunch")
print("   • Bottom-right: Smokers at Dinner")
print()
print("   Each point is colored by the day of the week!")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 COMMAND SUMMARY - FACETGRID
# ═══════════════════════════════════════════════════════════════════════════════
# sns.FacetGrid(data, col=, row=)  → Create grid structure
#   col='column_name'              → Split by categories into columns
#   row='column_name'              → Split by categories into rows
#   hue='column_name'              → Color code within facets
#   height=4                       → Height of each facet (inches)
#   aspect=1.2                     → Width = height × aspect
#   col_wrap=3                     → Wrap columns after N facets
#   palette='deep'                 → Color palette
#
# g.map(function, 'x', 'y')        → Simple mapping (for plt functions)
# g.map_dataframe(function, ...)   → Full DataFrame access (for sns)
# g.add_legend()                   → Add shared legend
# g.set_axis_labels()              → Set x/y labels for all facets
# g.set_titles()                   → Set individual facet titles
# g.fig.suptitle()                 → Add overall figure title
# ═══════════════════════════════════════════════════════════════════════════════

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# FACETGRID EXAMPLE 2: HISTOGRAMS BY CATEGORY
# ═══════════════════════════════════════════════════════════════════════════════
# This creates a row of histograms, one for each iris species

# ─── Create Grid with Only Columns (no rows) ────────────────────────────────────
# When you only specify col=, you get a single row of facets

g = sns.FacetGrid(iris,           # The iris dataset
                  col='species',   # One column per species (setosa, versicolor, virginica)
                  height=4,        # Height of each facet
                  aspect=1)        # Square facets

# ─── Map Histogram to Each Facet ────────────────────────────────────────────────
# g.map() is used for functions that take simple arguments
# Different from g.map_dataframe() which passes the full DataFrame
#
# Here we pass: function, column_name, and additional keyword arguments

g.map(sns.histplot,               # Function to apply
      'petal_length',             # Column to plot (as positional arg)
      kde=True,                   # Add density curve
      color='#3498db')            # Blue color for all bars

# Add overall title
g.fig.suptitle('🌸 Petal Length Distribution by Species', y=1.02, fontsize=14, fontweight='bold')

plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 map() vs map_dataframe()
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 WHEN TO USE EACH:")
print("   • g.map(func, 'x', 'y') → For matplotlib functions or simple seaborn calls")
print("   • g.map_dataframe(func, x='col', y='col') → When you need hue= or full DataFrame")
print()
print("   In this example, map() works because we only plot one variable (petal_length)")
print("   and don't need separate colors within each facet.")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 ALTERNATIVE: col_wrap FOR MANY CATEGORIES
# ═══════════════════════════════════════════════════════════════════════════════
# If you have many categories, use col_wrap to limit columns per row:
# g = sns.FacetGrid(df, col='category', col_wrap=3, height=3)
# This would create rows of 3 facets each
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ---
#
# # 4. Choosing the Right Chart
#
# Selecting the appropriate visualization is crucial for effective communication.
#
# ## 🎯 The Golden Rule
#
# > **Ask yourself: "What question am I trying to answer?"**
#
# ## Chart Selection Decision Tree
#
# ```
# What do you want to show?
# │
# ├── 📊 COMPARISON (comparing values across categories)
# │   ├── Few categories → Vertical Bar Chart
# │   ├── Many categories → Horizontal Bar Chart
# │   ├── Over time → Line Chart
# │   └── Multiple series → Grouped Bar Chart
# │
# ├── 📈 DISTRIBUTION (how data is spread)
# │   ├── Single variable → Histogram
# │   ├── Show shape → KDE Plot
# │   ├── Compare groups → Multiple Histograms or Violin Plot
# │   └── Summary + outliers → Box Plot
# │
# ├── 🔗 RELATIONSHIP (correlation between variables)
# │   ├── Two variables → Scatter Plot
# │   ├── With regression → sns.regplot()
# │   ├── Many variables → Pair Plot or Heatmap
# │   └── Show density → Bubble Chart
# │
# ├── 🥧 COMPOSITION (parts of a whole)
# │   ├── ≤7 categories → Pie or Donut Chart
# │   ├── Many categories → Stacked Bar Chart
# │   └── Over time → Stacked Area Chart
# │
# └── ⏰ TREND (change over time)
#     ├── Single series → Line Chart
#     ├── Multiple series → Multi-line Chart
#     └── With uncertainty → Line + Confidence Band
# ```
#
# ## Quick Reference Table
#
# | Question | Chart Type | Seaborn Function |
# |----------|------------|------------------|
# | How is this distributed? | Histogram | `sns.histplot()` |
# | How do groups compare? | Bar Chart | `sns.barplot()` |
# | Is there a relationship? | Scatter Plot | `sns.scatterplot()` |
# | What's the trend? | Line Chart | `sns.lineplot()` |
# | What are the outliers? | Box Plot | `sns.boxplot()` |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# VISUAL CHART TYPE REFERENCE GUIDE
# ═══════════════════════════════════════════════════════════════════════════════
# This cell creates a visual "cheat sheet" of 8 common chart types
# Each chart shows WHEN to use it and a simple example

# ─── Create 2×4 Grid of Subplots ────────────────────────────────────────────────
fig, axes = plt.subplots(2, 4, figsize=(18, 10))
fig.suptitle('📊 Chart Type Reference Guide', fontsize=16, fontweight='bold', y=1.02)

np.random.seed(42)

# ─── 1. BAR CHART: Comparing Categories ─────────────────────────────────────────
# USE FOR: Comparing values across distinct categories
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]
axes[0, 0].bar(categories, values, color='#3498db', edgecolor='white')
axes[0, 0].set_title('📊 Bar Chart\n"Comparison among items"', fontweight='bold')

# ─── 2. LINE CHART: Trends Over Time ────────────────────────────────────────────
# USE FOR: Showing how values change over time or continuous variable
x = np.arange(10)
y = np.cumsum(np.random.randn(10))  # Cumulative sum creates trending data
axes[0, 1].plot(x, y, marker='o', color='#e74c3c', linewidth=2)
axes[0, 1].set_title('📈 Line Chart\n"Trends over time"', fontweight='bold')

# ─── 3. SCATTER PLOT: Relationships Between Variables ───────────────────────────
# USE FOR: Showing correlation or patterns between two numeric variables
x = np.random.rand(50) * 100
y = x * 0.7 + np.random.randn(50) * 15  # y correlated with x plus noise
axes[0, 2].scatter(x, y, alpha=0.6, color='#2ecc71', s=60)
axes[0, 2].set_title('🔵 Scatter Plot\n"Relationships"', fontweight='bold')

# ─── 4. PIE CHART: Parts of a Whole ─────────────────────────────────────────────
# USE FOR: Showing composition (parts that sum to 100%)
# LIMIT: Best with ≤7 categories
sizes = [35, 30, 20, 15]  # Should sum to 100
axes[0, 3].pie(sizes, labels=['A', 'B', 'C', 'D'], autopct='%1.0f%%', 
               colors=['#3498db', '#e74c3c', '#2ecc71', '#f39c12'])
axes[0, 3].set_title('🥧 Pie Chart\n"Part-to-whole"', fontweight='bold')

# ─── 5. HISTOGRAM: Distribution of One Variable ─────────────────────────────────
# USE FOR: Showing how frequently values occur (distribution shape)
data = np.random.normal(50, 15, 500)  # Generate normally distributed data
axes[1, 0].hist(data, bins=20, color='#9b59b6', edgecolor='white')
axes[1, 0].set_title('📉 Histogram\n"Distribution"', fontweight='bold')

# ─── 6. BOX PLOT: Distribution Summary + Outliers ───────────────────────────────
# USE FOR: Comparing distributions and identifying outliers
# Shows: median, quartiles, range, and outliers
data = [np.random.normal(0, std, 100) for std in range(1, 5)]
bp = axes[1, 1].boxplot(data, patch_artist=True)
colors = ['#3498db', '#e74c3c', '#2ecc71', '#f39c12']
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
axes[1, 1].set_title('📦 Box Plot\n"Spread & Outliers"', fontweight='bold')

# ─── 7. HEATMAP: Matrix Values ──────────────────────────────────────────────────
# USE FOR: Showing patterns in 2D matrix data (correlations, counts by 2 categories)
matrix = np.random.rand(5, 5)  # 5×5 matrix of random values
im = axes[1, 2].imshow(matrix, cmap='YlOrRd')  # imshow displays 2D array as image
axes[1, 2].set_title('🔥 Heatmap\n"Matrix values"', fontweight='bold')

# ─── 8. AREA CHART: Cumulative Trends ───────────────────────────────────────────
# USE FOR: Showing cumulative totals or stacked trends over time
x = np.arange(10)
y1 = np.random.randint(20, 50, 10)
y2 = np.random.randint(10, 30, 10)
axes[1, 3].fill_between(x, y1, alpha=0.5, label='A')  # Filled area
axes[1, 3].fill_between(x, y2, alpha=0.5, label='B')
axes[1, 3].legend()
axes[1, 3].set_title('📊 Area Chart\n"Cumulative trends"', fontweight='bold')

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 QUICK DECISION GUIDE
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 QUICK CHART SELECTION:")
print("   • 'How many?' → Bar chart")
print("   • 'How does it change?' → Line chart")
print("   • 'Is there a relationship?' → Scatter plot")
print("   • 'What's the proportion?' → Pie/Donut chart")
print("   • 'How is it distributed?' → Histogram")
print("   • 'What are the outliers?' → Box plot")
print("   • 'How do two categories interact?' → Heatmap")
print("   • 'How do parts stack up?' → Area chart")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 KEY FUNCTIONS USED IN THIS CELL
# ═══════════════════════════════════════════════════════════════════════════════
# ax.bar(x, y)           → Vertical bar chart
# ax.plot(x, y)          → Line chart
# ax.scatter(x, y)       → Scatter plot
# ax.pie(sizes)          → Pie chart
# ax.hist(data)          → Histogram
# ax.boxplot(data)       → Box plot
# ax.imshow(matrix)      → Heatmap from 2D array
# ax.fill_between(x, y)  → Area chart
# np.cumsum()            → Cumulative sum (creates trending data)
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ## Common Visualization Mistakes to Avoid
#
# Learning what **NOT** to do is just as important as learning best practices!
#
# ### ⚠️ Red Flags in Data Visualization
#
# | ❌ Mistake | ✅ Better Practice | Why It Matters |
# |-----------|--------------------|----------------|
# | Using 3D charts for 2D data | Stick to 2D visualizations | 3D distorts perception of values |
# | Pie charts with many categories | Use bar charts for >7 categories | Hard to compare similar slices |
# | Truncating y-axis in bar charts | Start y-axis at 0 | Truncation exaggerates differences |
# | Rainbow color scales for sequential data | Use sequential color palettes | Rainbow implies categories, not order |
# | Too many elements on one chart | Simplify or use multiple charts | Cognitive overload reduces understanding |
# | Missing axis labels/titles | Always include clear labels | Readers can't interpret unlabeled charts |
# | Using only color to encode data | Add patterns, labels, or annotations | Not accessible for colorblind viewers |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# DEMONSTRATION: GOOD VS BAD VISUALIZATION PRACTICES
# ═══════════════════════════════════════════════════════════════════════════════
# These examples show common mistakes and how to fix them

fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# Sample data: Two companies with similar profits
companies = ['Company A', 'Company B']
profits = [100, 105]  # Only 5% difference

# ─── EXAMPLE 1: Truncated vs Full Y-Axis ────────────────────────────────────────

# ❌ BAD: Truncated Y-axis makes small difference look huge
# ax.set_ylim(min, max) sets the visible range of y-axis
axes[0, 0].bar(companies, profits, color=['#e74c3c', '#3498db'])
axes[0, 0].set_ylim(98, 106)  # Starting at 98 instead of 0!
axes[0, 0].set_title('❌ BAD: Truncated Y-Axis\n(Makes 5% difference look huge!)', 
                      fontweight='bold', color='red')
axes[0, 0].set_ylabel('Profit ($M)')

# ✅ GOOD: Y-axis starts at 0 (shows true proportion)
axes[0, 1].bar(companies, profits, color=['#e74c3c', '#3498db'])
axes[0, 1].set_ylim(0, 120)  # Proper range starting at 0
axes[0, 1].set_title('✅ GOOD: Y-Axis Starting at 0\n(Shows true proportion)', 
                      fontweight='bold', color='green')
axes[0, 1].set_ylabel('Profit ($M)')

# ─── EXAMPLE 2: Pie Chart vs Bar Chart for Many Categories ──────────────────────

# Create 12 categories - too many for pie chart
many_categories = [f'Cat {i}' for i in range(12)]
many_values = np.random.randint(5, 15, 12)

# ❌ BAD: Pie chart with too many slices
# Hard to compare: Which is bigger, Cat 3 or Cat 7?
axes[1, 0].pie(many_values, labels=many_categories, autopct='%1.0f%%')
axes[1, 0].set_title('❌ BAD: Pie Chart with 12 Categories\n(Hard to read!)', 
                      fontweight='bold', color='red')

# ✅ GOOD: Horizontal bar chart, sorted for easy comparison
# np.argsort() returns indices that would sort the array
sorted_idx = np.argsort(many_values)  # Indices to sort from smallest to largest

# Use list comprehension to reorder categories and values
sorted_categories = [many_categories[i] for i in sorted_idx]
sorted_values = [many_values[i] for i in sorted_idx]

# ax.barh() creates HORIZONTAL bars (easier to read category labels)
# plt.cm.viridis() creates colors from the viridis colormap
# np.linspace(0.2, 0.8, 12) creates 12 evenly spaced values between 0.2 and 0.8
axes[1, 1].barh(sorted_categories, sorted_values,
               color=plt.cm.viridis(np.linspace(0.2, 0.8, 12)))
axes[1, 1].set_title('✅ GOOD: Horizontal Bar Chart\n(Easy comparison!)', 
                      fontweight='bold', color='green')
axes[1, 1].set_xlabel('Value')

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 KEY LESSONS
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 VISUALIZATION INTEGRITY RULES:")
print("   1. BAR CHARTS: Always start y-axis at 0 (unless you have a good reason)")
print("   2. PIE CHARTS: Maximum 7 categories (use 'Other' to combine small values)")
print("   3. SORT DATA: In bar charts, sorting helps comparison")
print("   4. HORIZONTAL BARS: Better when category names are long")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 COMMANDS USED
# ═══════════════════════════════════════════════════════════════════════════════
# ax.set_ylim(min, max)      → Set y-axis visible range
# ax.barh(y, width)          → Horizontal bar chart
# np.argsort(array)          → Get indices that would sort array
# plt.cm.viridis(values)     → Get colors from viridis colormap
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ---
#
# # 5. Storytelling with Data
#
# Effective data visualization isn't just about creating charts—it's about **telling a compelling story that drives action**.
#
# ## The Data Storytelling Framework
#
# Every good data story has three parts:
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │  1. CONTEXT → Set the scene                             │
# │     "What's the current situation?"                     │
# │     Example: "Sales have been tracked for 5 quarters"   │
# ├─────────────────────────────────────────────────────────┤
# │  2. CONFLICT → Identify the problem/opportunity         │
# │     "What needs to change?"                             │
# │     Example: "We're losing market share to competitors" │
# ├─────────────────────────────────────────────────────────┤
# │  3. RESOLUTION → Present the insight + action           │
# │     "What should we do about it?"                       │
# │     Example: "Increase marketing spend on Product A"    │
# └─────────────────────────────────────────────────────────┘
# ```
#
# ## 🎯 Key Principles of Data Storytelling
#
# | Principle | What It Means | How To Do It |
# |-----------|---------------|--------------|
# | **Lead with insight** | Don't make readers search for it | Put the main finding in the title |
# | **Use strategic emphasis** | Draw attention to what matters | Use color, size, or annotations |
# | **Remove clutter** | Every element should earn its place | Delete gridlines, borders, legends if not needed |
# | **Tell one story per chart** | Don't overwhelm | Split complex insights into multiple visuals |
# | **Design for your audience** | Executives ≠ Analysts | Simplify for decision-makers |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# STORYTELLING EXAMPLE: QUARTERLY BUSINESS REVIEW
# ═══════════════════════════════════════════════════════════════════════════════
# This demonstrates how to create a multi-panel visualization that tells a 
# complete story with context, conflict, resolution, and call-to-action

# ─── STEP 1: Prepare Your Data ──────────────────────────────────────────────────
np.random.seed(42)

# Time periods (our x-axis across panels)
quarters = ['Q1 2024', 'Q2 2024', 'Q3 2024', 'Q4 2024', 'Q1 2025']

# Three data series for comparison
actual_sales = [850, 920, 980, 1150, 1280]     # Our company: growing trend
target_sales = [900, 950, 1000, 1050, 1100]   # Targets we set
competitor_sales = [800, 850, 920, 1000, 1050] # Main competitor

# ─── STEP 2: Create 2×2 Dashboard Layout ────────────────────────────────────────
# This layout tells 4 connected stories:
#   Panel 1: Are we hitting targets? (Context)
#   Panel 2: How do we compare to competition? (Conflict)
#   Panel 3: Where is growth coming from? (Analysis)
#   Panel 4: What should we do? (Resolution/Action)

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('📊 Quarterly Business Review: Sales Performance Story', 
             fontsize=16, fontweight='bold', y=1.02)

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 1: Target vs Actual (The Big Picture)
# Story: "We're exceeding our targets"
# ═══════════════════════════════════════════════════════════════════════════════
ax1 = axes[0, 0]

# Create grouped bar chart (actual vs target side by side)
x = np.arange(len(quarters))  # x positions: 0, 1, 2, 3, 4
width = 0.35                   # Bar width

# Plot bars offset from center position
# x - width/2 → left bars (actual)
# x + width/2 → right bars (target)
bars1 = ax1.bar(x - width/2, actual_sales, width, label='Actual', 
                color='#27ae60', edgecolor='white')
bars2 = ax1.bar(x + width/2, target_sales, width, label='Target', 
                color='#bdc3c7', edgecolor='white')

# Add checkmarks where we beat targets (strategic annotation!)
for i, (actual, target) in enumerate(zip(actual_sales, target_sales)):
    if actual > target:
        # ax.annotate() adds text with optional arrow
        ax1.annotate('✓', xy=(i - width/2, actual + 20), 
                     fontsize=16, ha='center', color='green')

ax1.set_title('🎯 Story 1: Exceeding Targets\n"We beat targets in 4 of 5 quarters"', 
              fontweight='bold', fontsize=11)
ax1.set_xticks(x)
ax1.set_xticklabels(quarters)
ax1.set_ylabel('Sales ($K)')
ax1.legend()
ax1.set_ylim(0, 1500)

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 2: Us vs Competition (The Trend)
# Story: "We're outpacing the competition"
# ═══════════════════════════════════════════════════════════════════════════════
ax2 = axes[0, 1]

# Line plot for trends (better than bars for showing change over time)
ax2.plot(quarters, actual_sales, marker='o', linewidth=3, markersize=10, 
         color='#3498db', label='Our Sales')
ax2.plot(quarters, competitor_sales, marker='s', linewidth=2, markersize=8, 
         color='#e74c3c', linestyle='--', alpha=0.7, label='Competitor')

# Annotate the key insight - the widening gap
# xy = where arrow points, xytext = where text appears
ax2.annotate('Gap widening!\n+$230K', 
             xy=(4, 1280),           # Arrow points to our Q1 2025 value
             xytext=(3.5, 1380),     # Text positioned above
             fontsize=10, ha='center', color='#27ae60', fontweight='bold',
             arrowprops=dict(arrowstyle='->', color='#27ae60'))

# Fill the gap between lines to emphasize it visually
ax2.fill_between(quarters, competitor_sales, actual_sales, 
                 alpha=0.2, color='#27ae60')

ax2.set_title('📈 Story 2: Outpacing Competition\n"We\'re growing faster than competitors"', 
              fontweight='bold', fontsize=11)
ax2.set_ylabel('Sales ($K)')
ax2.legend()
ax2.set_ylim(700, 1500)

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 3: Growth Breakdown (The Analysis)
# Story: "Products A & B are driving our growth"
# ═══════════════════════════════════════════════════════════════════════════════
ax3 = axes[1, 0]

products = ['Product A', 'Product B', 'Product C', 'Product D']
q1_sales = [300, 250, 200, 100]      # Q1 2024 sales
q5_sales = [450, 400, 280, 150]      # Q1 2025 sales

# Calculate year-over-year growth percentage
# Formula: ((new - old) / old) * 100
growth = [(q5 - q1) / q1 * 100 for q1, q5 in zip(q1_sales, q5_sales)]

# Color bars by whether they hit 40% growth target
colors = ['#27ae60' if g > 40 else '#3498db' for g in growth]

# Horizontal bar chart (better for category names)
bars = ax3.barh(products, growth, color=colors, edgecolor='white')

# Add value labels at end of each bar
for bar, g in zip(bars, growth):
    ax3.text(bar.get_width() + 2,                    # X position (end of bar + offset)
             bar.get_y() + bar.get_height()/2,       # Y position (middle of bar)
             f'+{g:.0f}%',                           # Label text
             va='center', fontweight='bold')

# Reference line for target growth
ax3.axvline(x=40, color='red', linestyle='--', alpha=0.7, 
            label='40% growth target')

ax3.set_title('🚀 Story 3: Growth Drivers\n"Products A & B are our growth engines"', 
              fontweight='bold', fontsize=11)
ax3.set_xlabel('YoY Growth (%)')
ax3.legend()

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 4: The Call to Action (The Resolution)
# Story: "Here's what we should do next"
# ═══════════════════════════════════════════════════════════════════════════════
ax4 = axes[1, 1]
ax4.axis('off')  # Hide axes - this panel is just for text

# Create summary box with key takeaways and recommendations
summary_text = """
📋 KEY TAKEAWAYS

✅ Exceeded targets in 4 of 5 quarters
✅ Growing 20% faster than main competitor  
✅ Products A & B driving 65% of growth

🎯 RECOMMENDED ACTIONS

1. Increase marketing spend on Products A & B
2. Investigate Product D underperformance
3. Set aggressive Q2 2025 target: $1,400K

💰 PROJECTED IMPACT

If trends continue: +$500K annual revenue
"""

# ax.text() with transform=ax.transAxes uses 0-1 coordinates
# (0,0) = bottom-left, (1,1) = top-right of axes area
ax4.text(0.1, 0.9, summary_text, 
         transform=ax4.transAxes,    # Use axes coordinates (0-1)
         fontsize=12,
         verticalalignment='top',
         fontfamily='monospace',     # Fixed-width font for alignment
         bbox=dict(boxstyle='round', facecolor='#ecf0f1', 
                   edgecolor='#bdc3c7', alpha=0.8))

ax4.set_title('📝 Story 4: The Call to Action', fontweight='bold', fontsize=11)

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 STORYTELLING TECHNIQUES USED
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 STORYTELLING TECHNIQUES IN THIS DASHBOARD:")
print("   1. TITLES TELL THE STORY: Each panel title states the insight")
print("   2. STRATEGIC COLOR: Green = good, Red = competitor/target")
print("   3. ANNOTATIONS: Checkmarks, arrows, labels highlight insights")
print("   4. FILL BETWEEN: Shows the gap visually, not just numerically")
print("   5. REFERENCE LINES: axvline/axhline show targets/benchmarks")
print("   6. CALL TO ACTION: Final panel tells reader what to DO with the data")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 KEY COMMANDS USED
# ═══════════════════════════════════════════════════════════════════════════════
# fig, axes = plt.subplots(2, 2)  → Create 2×2 grid of subplots
# ax.bar(x - width/2, y, width)   → Offset bars for grouped bar chart
# ax.annotate(text, xy=, xytext=) → Add text with optional arrow
# ax.fill_between(x, y1, y2)      → Fill area between two lines
# ax.axvline(x=value)             → Add vertical reference line
# ax.axis('off')                  → Hide axes for text-only panel
# ax.text(..., transform=ax.transAxes) → Position text in axes coordinates
# bbox=dict(boxstyle='round', ...) → Add box around text
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ## Using Color Strategically
#
# Color is one of the most powerful tools for guiding attention. Use it intentionally!
#
# ### 🎨 Three Color Strategies
#
# | Strategy | When to Use | Example |
# |----------|-------------|---------|
# | **Highlight exceptions** | Show what's different | Gray bars + one red bar |
# | **Sequential color** | Show magnitude | Light → Dark based on value |
# | **Categorical color** | Group by category | Different color per quarter |
#
# ### ⚠️ Color Tips
# - **Gray is your friend** - Use it for context/background data
# - **Limit bright colors** - 1-2 bright colors for emphasis only
# - **Consider colorblind users** - Avoid red/green alone, use patterns too

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# STRATEGIC USE OF COLOR TO EMPHASIZE INSIGHTS
# ═══════════════════════════════════════════════════════════════════════════════
# Same data, three different color strategies = three different stories

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Sample data: Monthly performance scores
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
performance = [85, 82, 88, 91, 78, 72, 75, 89, 94, 97, 93, 99]
target = 85  # Performance target

# ═══════════════════════════════════════════════════════════════════════════════
# STRATEGY 1: HIGHLIGHT EXCEPTIONS
# ═══════════════════════════════════════════════════════════════════════════════
# Goal: Draw attention to problems (below target) and success (best month)
# Technique: Gray out everything except what matters

# List comprehension creates colors based on condition
# Red for below target, gray for context
colors1 = ['#e74c3c' if p < target else '#bdc3c7' for p in performance]
colors1[-1] = '#27ae60'  # Override last month (December) to green - it's the best!

axes[0].bar(months, performance, color=colors1, edgecolor='white')

# Add reference line for target
# ax.axhline() draws a horizontal line across the entire plot
axes[0].axhline(y=target, color='#3498db', linestyle='--', linewidth=2, 
                label=f'Target ({target}%)')

axes[0].set_title('Strategy 1: Highlight Exceptions\n"3 months below target, December was best"', 
                  fontweight='bold')
axes[0].set_ylabel('Performance Score')
axes[0].legend()

# ═══════════════════════════════════════════════════════════════════════════════
# STRATEGY 2: SEQUENTIAL COLOR (Color by Magnitude)
# ═══════════════════════════════════════════════════════════════════════════════
# Goal: Show intensity/magnitude at a glance
# Technique: Use colormap where intensity = value

# plt.Normalize() creates a mapping from data range to [0, 1]
norm = plt.Normalize(min(performance), max(performance))

# plt.cm.RdYlGn() is a colormap (Red-Yellow-Green)
# Passing normalized values returns colors
# Low values → Red, Medium → Yellow, High → Green
colors2 = plt.cm.RdYlGn(norm(performance))

axes[1].bar(months, performance, color=colors2, edgecolor='white')
axes[1].set_title('Strategy 2: Sequential Colors\n"Color intensity shows performance level"', 
                  fontweight='bold')
axes[1].set_ylabel('Performance Score')

# ═══════════════════════════════════════════════════════════════════════════════
# STRATEGY 3: CATEGORICAL COLOR (Color by Group)
# ═══════════════════════════════════════════════════════════════════════════════
# Goal: Enable comparison between groups (quarters)
# Technique: Assign distinct color to each category

# Map each month to its quarter (1-4)
quarters = [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4]

# Define color for each quarter
quarter_colors = {1: '#3498db', 2: '#e74c3c', 3: '#2ecc71', 4: '#f39c12'}

# Create color list by looking up each month's quarter
colors3 = [quarter_colors[q] for q in quarters]

axes[2].bar(months, performance, color=colors3, edgecolor='white')
axes[2].set_title('Strategy 3: Categorical Colors\n"Group by quarters for comparison"', 
                  fontweight='bold')
axes[2].set_ylabel('Performance Score')

# Create custom legend using matplotlib patches
# matplotlib.patches.Patch creates a colored rectangle for legend
import matplotlib.patches as mpatches
legend_patches = [mpatches.Patch(color=c, label=f'Q{q}') 
                  for q, c in quarter_colors.items()]
axes[2].legend(handles=legend_patches, loc='lower right')

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 WHEN TO USE EACH STRATEGY
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 COLOR STRATEGY GUIDE:")
print("   • HIGHLIGHT EXCEPTIONS: When you want to focus on problems/wins")
print("   • SEQUENTIAL: When value magnitude is the main story")
print("   • CATEGORICAL: When comparing groups is the main story")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 KEY COMMANDS USED
# ═══════════════════════════════════════════════════════════════════════════════
# [color if condition else other for item in list]  → Conditional colors
# plt.Normalize(min, max)                            → Map values to 0-1
# plt.cm.RdYlGn(values)                              → Get colors from colormap
# ax.axhline(y=value)                                → Horizontal reference line
# import matplotlib.patches as mpatches              → For custom legend
# mpatches.Patch(color=, label=)                     → Create legend entry
# ax.legend(handles=[patches])                       → Add custom legend
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ## Adding Annotations for Context
#
# Annotations transform charts from "here's the data" to "here's what it means."
#
# ### 📝 Types of Annotations
#
# | Type | Function | Use Case |
# |------|----------|----------|
# | **Text labels** | `ax.text()` | Add notes anywhere |
# | **Arrows with text** | `ax.annotate()` | Point to specific data |
# | **Reference lines** | `ax.axhline()`, `ax.axvline()` | Show targets/benchmarks |
# | **Shaded regions** | `ax.axvspan()`, `ax.fill_between()` | Highlight periods |
# | **Summary boxes** | `ax.text(..., bbox=dict())` | Key takeaways |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CREATING ANNOTATED VISUALIZATIONS THAT TELL A COMPLETE STORY
# ═══════════════════════════════════════════════════════════════════════════════
# Scenario: Stock price analysis with annotations for key events
# This shows how annotations add context and meaning to raw data

np.random.seed(42)

# ─── STEP 1: Generate Stock Price Data ──────────────────────────────────────────
# pd.date_range() creates a sequence of dates
dates = pd.date_range('2024-01-01', periods=365, freq='D')

# Generate realistic-looking stock price with random walk
# Start at $100, then add cumulative random changes
# np.cumsum() = cumulative sum (running total)
price = 100 + np.cumsum(np.random.randn(365) * 2)

# ─── STEP 2: Define Key Events to Annotate ──────────────────────────────────────
# Dictionary maps date strings to (label, color) tuples
events = {
    '2024-03-15': ('Product Launch', 'green'),
    '2024-06-01': ('CEO Resignation', 'red'),
    '2024-08-20': ('Strong Earnings', 'green'),
    '2024-11-15': ('Market Expansion', 'blue')
}

# ─── STEP 3: Create the Base Plot ───────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(16, 8))

# Plot main price line
ax.plot(dates, price, linewidth=2, color='#2c3e50', alpha=0.8)

# Add subtle fill under the line for visual weight
ax.fill_between(dates, price.min(), price, alpha=0.1, color='#3498db')

# ─── STEP 4: Add Moving Average ─────────────────────────────────────────────────
# pd.Series().rolling(window).mean() calculates moving average
# This smooths out daily noise to show the trend
ma_30 = pd.Series(price).rolling(30).mean()
ax.plot(dates, ma_30, linewidth=2, color='#e74c3c', linestyle='--', 
        label='30-day MA', alpha=0.7)

# ─── STEP 5: Add Event Annotations ──────────────────────────────────────────────
for date_str, (label, color) in events.items():
    # Convert string date to pandas Timestamp
    event_date = pd.Timestamp(date_str)
    
    # Find the index of this date in our dates array
    # dates == event_date creates boolean array, argmax() returns index of first True
    idx = (dates == event_date).argmax()
    event_price = price[idx]
    
    # ─── ax.annotate() - The Key Annotation Function ────────────────────────────
    # PARAMETERS:
    #   text        → Label text to display
    #   xy          → Point the arrow points TO (the data point)
    #   xytext      → Where to place the text (offset from data point)
    #   fontsize    → Text size
    #   fontweight  → 'normal', 'bold'
    #   color       → Text color
    #   ha          → Horizontal alignment: 'left', 'center', 'right'
    #   arrowprops  → Dictionary defining arrow style
    #   bbox        → Box around text
    
    ax.annotate(label, 
                xy=(event_date, event_price),                    # Arrow points here
                xytext=(event_date + pd.Timedelta(days=20),     # Text offset 20 days right
                        event_price + 15),                       # and 15 units up
                fontsize=10, fontweight='bold', color=color,
                arrowprops=dict(arrowstyle='->',                # Arrow style
                               color=color, 
                               lw=1.5),                          # Line width
                bbox=dict(boxstyle='round,pad=0.3',             # Rounded box
                         facecolor='white',                      # White background
                         edgecolor=color,                        # Colored border
                         alpha=0.9))
    
    # Add vertical line at event date (subtle dotted line)
    ax.axvline(x=event_date, color=color, linestyle=':', alpha=0.5)
    
    # Add marker point at event location
    ax.scatter([event_date], [event_price], color=color, s=100, zorder=5, 
               edgecolors='white', linewidth=2)

# ─── STEP 6: Add Summary Box ────────────────────────────────────────────────────
# Create formatted summary string
summary = f"""📊 Performance Summary
Start: ${price[0]:.2f}
End: ${price[-1]:.2f}
Change: {((price[-1]/price[0])-1)*100:+.1f}%
Max: ${price.max():.2f}
Min: ${price.min():.2f}"""

# ax.text() with bbox creates a text box
# transform=ax.transAxes uses axes coordinates (0-1)
ax.text(0.02, 0.98, summary,                    # Position: top-left corner
        transform=ax.transAxes,                  # Use 0-1 axes coordinates
        fontsize=10,
        verticalalignment='top',                 # Align text from top
        fontfamily='monospace',                  # Fixed-width font
        bbox=dict(boxstyle='round',              # Rounded corners
                 facecolor='#ecf0f1',            # Light gray background
                 edgecolor='#bdc3c7',            # Border color
                 alpha=0.9))                     # Slight transparency

# ─── STEP 7: Final Formatting ───────────────────────────────────────────────────
ax.set_title('📈 TechCorp (TECH) Stock Price Analysis - 2024\nKey Events & Performance', 
             fontsize=14, fontweight='bold', pad=15)
ax.set_xlabel('Date', fontsize=11)
ax.set_ylabel('Stock Price ($)', fontsize=11)
ax.legend(loc='upper right')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 ANNOTATION COMMANDS SUMMARY
# ═══════════════════════════════════════════════════════════════════════════════
# ax.annotate(text, xy=, xytext=, arrowprops=)  → Text with arrow
#   xy=(x, y)                → Point arrow points to
#   xytext=(x, y)            → Where text is placed
#   arrowprops=dict(...)     → Arrow styling
#
# ax.axvline(x=value)        → Vertical line across plot
# ax.axhline(y=value)        → Horizontal line across plot
#
# ax.text(x, y, text, ...)   → Add text anywhere
#   transform=ax.transAxes   → Use 0-1 coordinates relative to axes
#   bbox=dict(...)           → Add box around text
#
# ax.scatter([x], [y])       → Add marker points
#   zorder=5                 → Draw on top of other elements
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ---
#
# # 6. Practice Projects
#
# Now let's apply everything we've learned in two realistic projects!
#
# ## Project 1: Visual Exploratory Data Analysis (EDA)
#
# ### 🏪 Scenario: Retail Store Sales Analysis
#
# You're a data analyst at a retail company. Your task is to explore sales data and create visualizations that answer key business questions:
#
# 1. **Which stores perform best?** (Composition - Pie chart)
# 2. **Which product categories drive revenue?** (Comparison - Bar chart)
# 3. **When do customers shop?** (Trend - Line & Heatmap)
# 4. **What affects spending?** (Relationship - Scatter, Box plots)
#
# ### Key Techniques Demonstrated:
# - `GridSpec` for complex dashboard layouts
# - Multiple chart types in one figure
# - Adding annotations and insights
# - Color strategies for emphasis

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PROJECT 1 - STEP 1: GENERATE RETAIL DATASET
# ═══════════════════════════════════════════════════════════════════════════════
# First, we create a realistic retail dataset to analyze

np.random.seed(42)  # For reproducibility

n_records = 1000  # Number of transactions

# ─── Create the Main DataFrame ──────────────────────────────────────────────────
# pd.DataFrame() creates a table from a dictionary of columns
# Each key = column name, each value = array of data

retail_data = pd.DataFrame({
    # Basic transaction info
    'transaction_id': range(1, n_records + 1),
    
    # Date column: pd.date_range() creates sequence of dates
    # freq='4H' means one record every 4 hours
    'date': pd.date_range('2024-01-01', periods=n_records, freq='4H'),
    
    # np.random.choice() randomly selects from options
    # p=[...] specifies probability for each option (must sum to 1)
    'store': np.random.choice(['Downtown', 'Mall', 'Suburb', 'Airport'], 
                              n_records, p=[0.3, 0.35, 0.25, 0.1]),
    
    'category': np.random.choice(['Electronics', 'Clothing', 'Food', 'Home', 'Beauty'], 
                                 n_records, p=[0.2, 0.25, 0.3, 0.15, 0.1]),
    
    'payment_method': np.random.choice(['Card', 'Cash', 'Mobile'], 
                                        n_records, p=[0.6, 0.25, 0.15]),
    
    # np.random.poisson() generates count data (good for "number of items")
    # λ=3 means average 3 items per transaction
    'items': np.random.poisson(3, n_records) + 1,  # +1 ensures at least 1 item
    
    # np.random.exponential() generates right-skewed money data (realistic!)
    # Mean = 75, then +10 ensures minimum ~$10
    'amount': np.random.exponential(75, n_records) + 10,
    
    # np.random.normal() generates normally distributed data
    # Mean=38, StdDev=12, then clip() limits range to 18-75
    'customer_age': np.random.normal(38, 12, n_records).clip(18, 75).astype(int),
    
    # Boolean membership flag
    'is_member': np.random.choice([True, False], n_records, p=[0.4, 0.6])
})

# ─── Add Derived Columns ────────────────────────────────────────────────────────
# Extract useful date components using pandas datetime accessor (.dt)

retail_data['day_of_week'] = retail_data['date'].dt.day_name()   # 'Monday', 'Tuesday'...
retail_data['hour'] = retail_data['date'].dt.hour                 # 0-23
retail_data['month'] = retail_data['date'].dt.month_name()        # 'January', 'February'...
retail_data['avg_item_value'] = retail_data['amount'] / retail_data['items']  # Calculated field

# ─── Display Dataset Info ───────────────────────────────────────────────────────
print("🛒 Retail Dataset Generated!")
print(f"   Shape: {retail_data.shape[0]} rows × {retail_data.shape[1]} columns")
print(f"   Date Range: {retail_data['date'].min().date()} to {retail_data['date'].max().date()}")
print(f"   Total Sales: ${retail_data['amount'].sum():,.0f}")
print("\n📊 Sample Records:")
display(retail_data.head())

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 DATA GENERATION TECHNIQUES USED
# ═══════════════════════════════════════════════════════════════════════════════
# pd.date_range(start, periods, freq)     → Generate date sequence
# np.random.choice(options, n, p=probs)   → Random sampling with probabilities
# np.random.poisson(λ, n)                 → Count data (good for quantities)
# np.random.exponential(mean, n)          → Right-skewed data (good for money)
# np.random.normal(mean, std, n)          → Bell-curve data (good for age/height)
# series.clip(min, max)                   → Limit values to range
# df['date'].dt.day_name()                → Extract day name from datetime
# ═══════════════════════════════════════════════════════════════════════════════

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PROJECT 1 - STEP 2: COMPLETE EDA DASHBOARD
# ═══════════════════════════════════════════════════════════════════════════════
# This creates an 8-panel dashboard answering key business questions

# ─── Create Figure with GridSpec Layout ─────────────────────────────────────────
# GridSpec allows flexible, non-uniform grid layouts
# Unlike plt.subplots(), GridSpec lets you span multiple cells

from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(18, 14))

# GridSpec(rows, cols) defines the grid
# hspace = height space between rows
# wspace = width space between columns
gs = GridSpec(3, 3, figure=fig, hspace=0.35, wspace=0.3)

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 1: SALES BY STORE (Pie Chart) - "Which stores perform best?"
# ═══════════════════════════════════════════════════════════════════════════════
ax1 = fig.add_subplot(gs[0, 0])  # Row 0, Column 0

# groupby().sum() aggregates data: total sales per store
store_sales = retail_data.groupby('store')['amount'].sum()

colors = ['#3498db', '#e74c3c', '#2ecc71', '#f39c12']
# explode pushes first slice outward for emphasis
ax1.pie(store_sales, labels=store_sales.index, autopct='%1.1f%%', 
        colors=colors, explode=[0.05, 0, 0, 0])
ax1.set_title('🏪 Sales Distribution by Store', fontweight='bold')

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 2: CATEGORY PERFORMANCE (Horizontal Bar) - "What categories drive revenue?"
# ═══════════════════════════════════════════════════════════════════════════════
ax2 = fig.add_subplot(gs[0, 1])  # Row 0, Column 1

# Sort values for easier comparison (smallest at bottom)
cat_sales = retail_data.groupby('category')['amount'].sum().sort_values()

# plt.cm.viridis() creates colors from colormap
# np.linspace(0.2, 0.8, n) creates n evenly spaced values
bars = ax2.barh(cat_sales.index, cat_sales.values, 
               color=plt.cm.viridis(np.linspace(0.2, 0.8, len(cat_sales))))
ax2.set_title('📦 Sales by Category', fontweight='bold')
ax2.set_xlabel('Total Sales ($)')

# Add value labels at end of each bar
for bar in bars:
    ax2.text(bar.get_width() + 500,                   # X: end of bar + offset
             bar.get_y() + bar.get_height()/2,        # Y: middle of bar
             f'${bar.get_width()/1000:.1f}K',         # Format as "$XXX.XK"
             va='center', fontsize=9)

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 3: DAILY PATTERN (Line Chart) - "Which days are busiest?"
# ═══════════════════════════════════════════════════════════════════════════════
ax3 = fig.add_subplot(gs[0, 2])  # Row 0, Column 2

# Define correct day order (pandas sorts alphabetically by default!)
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# groupby().mean() calculates average sale per day
# .reindex(day_order) forces our preferred order
daily_sales = retail_data.groupby('day_of_week')['amount'].mean().reindex(day_order)

ax3.plot(range(7), daily_sales.values, marker='o', linewidth=2, 
         markersize=8, color='#9b59b6')
ax3.fill_between(range(7), daily_sales.values, alpha=0.3, color='#9b59b6')
ax3.set_xticks(range(7))
ax3.set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
ax3.set_title('📅 Average Sales by Day', fontweight='bold')
ax3.set_ylabel('Avg Sale ($)')

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 4: HOURLY HEATMAP (spans 2 columns) - "When do different stores peak?"
# ═══════════════════════════════════════════════════════════════════════════════
ax4 = fig.add_subplot(gs[1, :2])  # Row 1, Columns 0-1 ([:2] means columns 0 and 1)

# pivot_table creates a 2D matrix: rows=store, columns=hour, values=avg amount
hourly_store = retail_data.pivot_table(values='amount', 
                                        index='store', 
                                        columns='hour', 
                                        aggfunc='mean')

sns.heatmap(hourly_store, cmap='YlOrRd', ax=ax4, annot=False, 
            cbar_kws={'label': 'Avg Sale ($)'})
ax4.set_title('🕐 Hourly Sales Pattern by Store (Heatmap)', fontweight='bold')
ax4.set_xlabel('Hour of Day')

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 5: TRANSACTION DISTRIBUTION (Histogram) - "What's our typical sale?"
# ═══════════════════════════════════════════════════════════════════════════════
ax5 = fig.add_subplot(gs[1, 2])  # Row 1, Column 2

sns.histplot(retail_data['amount'], kde=True, ax=ax5, color='#3498db', bins=30)

# Add median reference line
ax5.axvline(retail_data['amount'].median(), color='red', linestyle='--', 
            label=f'Median: ${retail_data["amount"].median():.0f}')
ax5.set_title('💵 Transaction Amount Distribution', fontweight='bold')
ax5.set_xlabel('Amount ($)')
ax5.legend()

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 6: MEMBER VS NON-MEMBER (Box Plot) - "Do members spend more?"
# ═══════════════════════════════════════════════════════════════════════════════
ax6 = fig.add_subplot(gs[2, 0])  # Row 2, Column 0

sns.boxplot(data=retail_data, x='is_member', y='amount', ax=ax6, palette='Set2')
ax6.set_xticklabels(['Non-Member', 'Member'])
ax6.set_title('🎫 Member vs Non-Member Spending', fontweight='bold')
ax6.set_ylabel('Transaction Amount ($)')

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 7: AGE VS SPENDING (Scatter) - "Does age affect spending?"
# ═══════════════════════════════════════════════════════════════════════════════
ax7 = fig.add_subplot(gs[2, 1])  # Row 2, Column 1

# .sample(200) randomly selects 200 rows (avoids overplotting)
sns.scatterplot(data=retail_data.sample(200), x='customer_age', y='amount', 
                hue='category', ax=ax7, alpha=0.7, s=60)
ax7.set_title('👥 Age vs Spending by Category', fontweight='bold')
ax7.set_xlabel('Customer Age')
ax7.set_ylabel('Amount ($)')
ax7.legend(loc='upper right', fontsize=8)

# ═══════════════════════════════════════════════════════════════════════════════
# PANEL 8: PAYMENT METHODS (Bar Chart) - "How do customers pay?"
# ═══════════════════════════════════════════════════════════════════════════════
ax8 = fig.add_subplot(gs[2, 2])  # Row 2, Column 2

# value_counts() counts occurrences of each category
payment_counts = retail_data['payment_method'].value_counts()

bars = ax8.bar(payment_counts.index, payment_counts.values, 
               color=['#3498db', '#2ecc71', '#f39c12'], edgecolor='white')

# Add count labels on each bar
for bar in bars:
    ax8.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 10,
             f'{int(bar.get_height())}', ha='center', fontweight='bold')
             
ax8.set_title('💳 Payment Method Distribution', fontweight='bold')
ax8.set_ylabel('Number of Transactions')

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 KEY TECHNIQUES IN THIS DASHBOARD
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 DASHBOARD TECHNIQUES DEMONSTRATED:")
print("   • GridSpec for flexible layout (spanning multiple columns)")
print("   • groupby() + agg functions for data summarization")
print("   • pivot_table() for 2D matrix creation")
print("   • Mixed chart types for different questions")
print("   • Reference lines (axvline) for context")
print("   • Value labels on bars for precise reading")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 KEY COMMANDS USED
# ═══════════════════════════════════════════════════════════════════════════════
# GridSpec(rows, cols)              → Define flexible grid layout
# fig.add_subplot(gs[row, col])     → Add subplot at grid position
# gs[1, :2]                         → Span columns 0-1 in row 1
# df.groupby('col')['val'].sum()    → Aggregate by group
# df.pivot_table(values, index, columns) → Create 2D summary
# series.reindex(order)             → Force specific order
# df.sample(n)                      → Random sample of rows
# series.value_counts()             → Count occurrences
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ## Project 2: Creating an Executive Summary Report
#
# ### 📊 Scenario: Present Key Findings to Leadership
#
# Executives don't have time to explore dashboards. They need:
# - **Clear KPIs** at a glance
# - **Key trends** highlighted
# - **Actionable insights** stated directly
#
# ### Executive Report Design Principles:
# 1. **Lead with numbers** - KPI cards at the top
# 2. **Show trends** - Are we improving?
# 3. **Highlight action items** - What to do next
# 4. **Minimize clutter** - Every element must earn its place

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PROJECT 2: EXECUTIVE SUMMARY REPORT
# ═══════════════════════════════════════════════════════════════════════════════
# This creates a polished report designed for leadership presentations

fig = plt.figure(figsize=(16, 12))

# ─── Create Custom GridSpec Layout ──────────────────────────────────────────────
# height_ratios controls the relative height of each row
# [1, 1.2, 1] means: row 0 = normal, row 1 = 20% taller, row 2 = normal
gs = GridSpec(3, 4, figure=fig, hspace=0.4, wspace=0.3,
              height_ratios=[1, 1.2, 1])

# ═══════════════════════════════════════════════════════════════════════════════
# ROW 1: KPI CARDS (4 metrics across the top)
# ═══════════════════════════════════════════════════════════════════════════════
# Define KPIs as list of tuples: (title, value, change, color)
kpis = [
    ('Total Revenue', f'${retail_data["amount"].sum()/1000:.1f}K', '↑ 12%', '#27ae60'),
    ('Transactions', f'{len(retail_data):,}', '↑ 8%', '#3498db'),
    ('Avg Order Value', f'${retail_data["amount"].mean():.2f}', '↑ 5%', '#9b59b6'),
    ('Member Rate', f'{retail_data["is_member"].mean()*100:.1f}%', '↑ 3%', '#f39c12')
]

# Create each KPI card
for i, (title, value, change, color) in enumerate(kpis):
    ax = fig.add_subplot(gs[0, i])  # Row 0, column i
    
    # Set up "canvas" for custom drawing
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.axis('off')  # Hide axes - we're just drawing shapes
    
    # Draw background rectangle (KPI card)
    # plt.Rectangle((x, y), width, height, ...) creates a rectangle shape
    rect = plt.Rectangle((0.05, 0.05), 0.9, 0.9,    # Position and size
                         facecolor=color, alpha=0.15, # Light fill color
                         edgecolor=color, linewidth=2, # Colored border
                         transform=ax.transAxes)       # Use 0-1 coordinates
    ax.add_patch(rect)  # Add shape to axes
    
    # Add text labels at different vertical positions
    ax.text(0.5, 0.75, title, ha='center', va='center', 
            fontsize=11, color='gray', fontweight='bold')
    ax.text(0.5, 0.45, value, ha='center', va='center', 
            fontsize=20, color=color, fontweight='bold')
    ax.text(0.5, 0.15, change, ha='center', va='center', 
            fontsize=12, color='green', fontweight='bold')

# ═══════════════════════════════════════════════════════════════════════════════
# ROW 2, LEFT: REVENUE TREND (main chart spanning 3 columns)
# ═══════════════════════════════════════════════════════════════════════════════
ax_main = fig.add_subplot(gs[1, :3])  # Row 1, columns 0-2

# Group by month and sum revenue
# dt.to_period('M') converts datetime to monthly period
monthly_revenue = retail_data.groupby(retail_data['date'].dt.to_period('M'))['amount'].sum()
monthly_revenue.index = monthly_revenue.index.astype(str)  # Convert period to string

# Combination chart: bars + line
ax_main.bar(monthly_revenue.index, monthly_revenue.values, 
            color='#3498db', edgecolor='white', alpha=0.7)
ax_main.plot(monthly_revenue.index, monthly_revenue.values, 
             marker='o', color='#e74c3c', linewidth=2, markersize=8)

ax_main.set_title('📈 Monthly Revenue Trend', fontweight='bold', fontsize=12)
ax_main.set_ylabel('Revenue ($)')
ax_main.tick_params(axis='x', rotation=45)

# Format y-axis as currency (e.g., "$85K")
# FuncFormatter takes a function that receives value and position
ax_main.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}K'))

# ═══════════════════════════════════════════════════════════════════════════════
# ROW 2, RIGHT: STORE RANKINGS (small chart in column 3)
# ═══════════════════════════════════════════════════════════════════════════════
ax_side = fig.add_subplot(gs[1, 3])  # Row 1, column 3

store_perf = retail_data.groupby('store')['amount'].sum().sort_values(ascending=True)

# Color strategy: gray for context, green for top performer
colors_side = ['#bdc3c7', '#bdc3c7', '#bdc3c7', '#27ae60']

ax_side.barh(store_perf.index, store_perf.values, color=colors_side)
ax_side.set_title('🏆 Store Rankings', fontweight='bold', fontsize=12)
ax_side.set_xlabel('Total Revenue ($)')

# ═══════════════════════════════════════════════════════════════════════════════
# ROW 3, LEFT: STACKED BAR CHART (Category mix by store)
# ═══════════════════════════════════════════════════════════════════════════════
ax_bottom1 = fig.add_subplot(gs[2, 0:2])  # Row 2, columns 0-1

# Create pivot table: rows=store, columns=category, values=sales
# unstack() converts multi-index to columns
cat_by_store = retail_data.groupby(['store', 'category'])['amount'].sum().unstack()

# df.plot(kind='bar', stacked=True) creates stacked bar directly from DataFrame
cat_by_store.plot(kind='bar', stacked=True, ax=ax_bottom1, 
                  colormap='viridis', edgecolor='white')

ax_bottom1.set_title('📊 Category Mix by Store', fontweight='bold', fontsize=11)
ax_bottom1.set_ylabel('Revenue ($)')
# Position legend outside plot
ax_bottom1.legend(title='Category', bbox_to_anchor=(1.02, 1), fontsize=8)
ax_bottom1.tick_params(axis='x', rotation=0)

# ═══════════════════════════════════════════════════════════════════════════════
# ROW 3, RIGHT: KEY FINDINGS TEXT BOX
# ═══════════════════════════════════════════════════════════════════════════════
ax_text = fig.add_subplot(gs[2, 2:])  # Row 2, columns 2-3
ax_text.axis('off')  # Text-only panel

# Create formatted findings string (multiline string with triple quotes)
findings = """
📋 KEY FINDINGS & RECOMMENDATIONS

✅ STRENGTHS:
• Mall store leads revenue (+35% vs avg)
• Food category shows strong performance
• Weekend sales 40% higher than weekdays

⚠️ OPPORTUNITIES:
• Airport store underperforming
• Beauty category needs attention
• Member conversion rate below target

🎯 ACTIONS:
1. Increase Airport marketing budget
2. Launch Beauty category promotion
3. Implement member referral program
"""

# Add text with background box
ax_text.text(0.05, 0.95, findings, 
            transform=ax_text.transAxes, fontsize=10,
            verticalalignment='top', fontfamily='sans-serif',
            bbox=dict(boxstyle='round', facecolor='#f8f9fa', 
                     edgecolor='#dee2e6', alpha=0.9))

# ─── Add Main Title ─────────────────────────────────────────────────────────────
fig.suptitle('📊 EXECUTIVE SUMMARY: Retail Performance Report', 
             fontsize=16, fontweight='bold', y=1.02)

plt.tight_layout()
plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 EXECUTIVE REPORT TECHNIQUES
# ═══════════════════════════════════════════════════════════════════════════════
print("\n💡 EXECUTIVE REPORT BEST PRACTICES:")
print("   1. KPI CARDS: Lead with key numbers at the top")
print("   2. MAIN CHART: Feature the most important trend prominently")
print("   3. SUPPORTING CHARTS: Add context without overwhelming")
print("   4. TEXT SUMMARY: State insights and actions directly")
print("   5. COLOR STRATEGY: Highlight what matters, gray out context")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 KEY COMMANDS USED
# ═══════════════════════════════════════════════════════════════════════════════
# GridSpec(..., height_ratios=[1,1.2,1]) → Control row heights
# plt.Rectangle((x,y), w, h)             → Draw shape on axes
# ax.add_patch(shape)                    → Add shape to plot
# df.groupby().unstack()                 → Create pivot table
# df.plot(kind='bar', stacked=True)      → Stacked bar from DataFrame
# plt.FuncFormatter(lambda x,p: ...)     → Custom axis label format
# bbox_to_anchor=(x, y)                  → Position legend outside plot
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ## Saving Visualizations
#
# Once you've created a great visualization, you'll want to save it for presentations, reports, or web pages.
#
# ### 📁 Common Export Formats
#
# | Format | Best For | Pros | Cons |
# |--------|----------|------|------|
# | **PNG** | Presentations, Documents | High quality, universal | Large files at high DPI |
# | **PDF** | Print, Academic papers | Vector (scales perfectly) | Not for web |
# | **SVG** | Web, Interactive | Scalable, small files | Browser compatibility |
# | **JPEG** | Photos with charts | Small file size | Lossy compression |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# SAVING VISUALIZATIONS - EXPORT TO FILES
# ═══════════════════════════════════════════════════════════════════════════════

# ─── Create a Sample Plot to Save ───────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(['A', 'B', 'C', 'D'], [25, 40, 30, 55], color='#3498db')
ax.set_title('Sample Chart for Export', fontweight='bold')
ax.set_ylabel('Values')

# ─── Saving Figures ─────────────────────────────────────────────────────────────
# fig.savefig() saves the current figure to a file
#
# PARAMETERS:
#   filename     → File path with extension (determines format)
#   dpi          → Dots per inch (resolution): 72=screen, 300=print
#   bbox_inches  → 'tight' removes extra whitespace around figure
#   facecolor    → Background color (default matches figure)
#   transparent  → True for transparent background (PNG only)
#   quality      → JPEG quality 1-100 (higher = better but larger)

# UNCOMMENT THESE LINES TO ACTUALLY SAVE FILES:

# High-resolution PNG (best for presentations)
# fig.savefig('chart.png', dpi=300, bbox_inches='tight')

# PDF for print quality (vector - scales perfectly)
# fig.savefig('chart.pdf', bbox_inches='tight')

# SVG for web (vector, editable in Illustrator)
# fig.savefig('chart.svg', bbox_inches='tight')

# JPEG with compression (smaller files, slight quality loss)
# fig.savefig('chart.jpg', dpi=150, quality=95)

# PNG with transparent background
# fig.savefig('chart_transparent.png', dpi=300, bbox_inches='tight', transparent=True)

plt.show()

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 EXPORT RECOMMENDATIONS
# ═══════════════════════════════════════════════════════════════════════════════
print("📁 WHEN TO USE EACH FORMAT:")
print()
print("   PNG (dpi=300, bbox_inches='tight')")
print("   └─ Best for: PowerPoint, Word documents, emails")
print("   └─ Why: Universal support, high quality")
print()
print("   PDF (bbox_inches='tight')")
print("   └─ Best for: Academic papers, printing, archiving")
print("   └─ Why: Vector graphics scale to any size")
print()
print("   SVG (bbox_inches='tight')")
print("   └─ Best for: Websites, interactive dashboards")
print("   └─ Why: Small files, CSS/JS customizable")
print()
print("   JPEG (dpi=150, quality=95)")
print("   └─ Best for: When file size matters")
print("   └─ Why: Good compression, but loses some quality")

# ═══════════════════════════════════════════════════════════════════════════════
# 📚 SAVEFIG COMMAND REFERENCE
# ═══════════════════════════════════════════════════════════════════════════════
# fig.savefig('file.png', dpi=300)      → High-res PNG
# fig.savefig('file.pdf')               → Vector PDF
# fig.savefig('file.svg')               → Scalable vector
# fig.savefig('file.jpg', quality=95)   → Compressed JPEG
#
# Common options:
#   dpi=300                  → Print quality resolution
#   bbox_inches='tight'      → Crop whitespace
#   transparent=True         → Transparent background (PNG)
#   facecolor='white'        → Set background color
#   pad_inches=0.1           → Add padding around figure
# ═══════════════════════════════════════════════════════════════════════════════

# %% [markdown]
# ---
#
# # 📝 Summary & Key Takeaways
#
# ## What You Learned in This Unit:
#
# ### 1. 📊 Visualization Fundamentals
# - Data visualization transforms numbers into insights humans can understand
# - The 4 principles: **Clarity, Accuracy, Efficiency, Aesthetics**
# - Anscombe's Quartet proved: always visualize—statistics alone can mislead!
#
# ### 2. 🎨 Matplotlib - The Foundation
# | Chart Type | Function | Best For |
# |------------|----------|----------|
# | Line Plot | `ax.plot()` | Trends over time |
# | Bar Chart | `ax.bar()` / `ax.barh()` | Category comparison |
# | Scatter Plot | `ax.scatter()` | Relationships |
# | Histogram | `ax.hist()` | Distribution |
# | Pie Chart | `ax.pie()` | Composition (≤7 slices) |
# | Box Plot | `ax.boxplot()` | Distribution + outliers |
#
# ### 3. 📈 Seaborn - Statistical Visualization
# | Category | Functions | Use Cases |
# |----------|-----------|-----------|
# | Distribution | `histplot()`, `kdeplot()`, `boxplot()`, `violinplot()` | How is data spread? |
# | Relationship | `scatterplot()`, `regplot()`, `pairplot()` | Are variables related? |
# | Categorical | `barplot()`, `countplot()`, `stripplot()` | Compare categories |
# | Matrix | `heatmap()`, `clustermap()` | Correlations, patterns |
#
# ### 4. 🎯 Choosing the Right Chart
# - **Comparison** → Bar charts
# - **Trend** → Line charts
# - **Relationship** → Scatter plots
# - **Distribution** → Histograms, box plots
# - **Composition** → Pie/donut charts (sparingly!)
#
# ### 5. 📖 Storytelling with Data
# - **Lead with insight** → Title should state the finding
# - **Use color strategically** → Gray for context, bright for emphasis
# - **Add annotations** → `ax.annotate()`, `ax.axvline()`, `ax.text()`
# - **Remove clutter** → Every element must earn its place
#
# ---
#
# ## 🎓 Key Commands Cheat Sheet
#
# ```python
# # SETUP
# import matplotlib.pyplot as plt
# import seaborn as sns
# fig, ax = plt.subplots(figsize=(10, 6))
#
# # MATPLOTLIB BASICS
# ax.plot(x, y)           # Line chart
# ax.bar(x, y)            # Vertical bars
# ax.barh(y, width)       # Horizontal bars
# ax.scatter(x, y)        # Scatter plot
# ax.hist(data, bins=20)  # Histogram
# ax.pie(sizes)           # Pie chart
#
# # CUSTOMIZATION
# ax.set_title('Title')
# ax.set_xlabel('X Label')
# ax.set_ylabel('Y Label')
# ax.legend()
# ax.grid(True, alpha=0.3)
#
# # ANNOTATIONS
# ax.annotate('Text', xy=(x,y), xytext=(x2,y2), arrowprops=dict(arrowstyle='->'))
# ax.axhline(y=value)     # Horizontal line
# ax.axvline(x=value)     # Vertical line
# ax.text(x, y, 'Text')   # Add text anywhere
#
# # SEABORN
# sns.histplot(data, kde=True)
# sns.boxplot(data=df, x='cat', y='val')
# sns.scatterplot(data=df, x='x', y='y', hue='group')
# sns.heatmap(matrix, annot=True, cmap='coolwarm')
# sns.pairplot(df, hue='species')
#
# # SAVING
# fig.savefig('chart.png', dpi=300, bbox_inches='tight')
# ```
#
# ---
#
# ## 🏋️ Practice Exercises
#
# Try these on your own to reinforce what you learned:
#
# 1. **Basic**: Create a bar chart comparing 5 products' sales, with the highest bar highlighted in a different color
#
# 2. **Intermediate**: Using the tips dataset (`sns.load_dataset('tips')`), create a FacetGrid showing tip distribution by day and time
#
# 3. **Advanced**: Create an executive dashboard for a dataset of your choice with:
#    - 3+ KPI cards
#    - At least 4 different chart types
#    - Strategic use of color
#    - Annotations highlighting key insights
#
# 4. **Challenge**: Recreate one visualization from a news article or report you find online
#
# ---
#
# ## 📚 Additional Resources
#
# - **Matplotlib Gallery**: https://matplotlib.org/stable/gallery/
# - **Seaborn Tutorial**: https://seaborn.pydata.org/tutorial.html
# - **Storytelling with Data (book)**: Cole Nussbaumer Knaflic
# - **Data Visualization Catalogue**: https://datavizcatalogue.com/
#
# ---
#
# **🎉 Congratulations!** You now have the skills to turn any dataset into compelling, professional visualizations that tell a story and drive action.
